# %% [markdown]
# <a href="https://colab.research.google.com/github/plthiyagu/AI-Engineering/blob/master/04-Matplotlib/Using_Seaborn%E2%80%99s_FacetGrid_Based_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
df = sns.load_dataset('mpg')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  ...  model_year  origin                       name
# 0  18.0          8         307.0  ...          70     usa  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...          70     usa          buick skylark 320
# 2  18.0          8         318.0  ...          70     usa         plymouth satellite
# 3  16.0          8         304.0  ...          70     usa              amc rebel sst
# 4  17.0          8         302.0  ...          70     usa                ford torino
#
# [5 rows x 9 columns]

# %%
sns.catplot(data=df, x="cylinders", y="displacement");

# %%
import seaborn as sns
df = sns.load_dataset('mpg')
# df.head()
sns.catplot(data=df, x="cylinders", y="displacement", col = 'origin', hue = 'model_year');

# %%
import seaborn as sns
df = sns.load_dataset('mpg')
# df.head()
sns.catplot(data=df, x="cylinders", y="displacement", col = 'origin', hue = 'model_year', kind = 'box');

# %%
df = sns.load_dataset('penguins')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
sns.pairplot(df, dropna = True);

# %%
import seaborn as sns
df = sns.load_dataset('penguins')
# df.head()
sns.pairplot(df, dropna = True, hue = 'island');

# %%
import seaborn as sns
df = sns.load_dataset('penguins')
# df.head()
sns.pairplot(df, dropna = True, hue = 'island', kind = 'kde');
