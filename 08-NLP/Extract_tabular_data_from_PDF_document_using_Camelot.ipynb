# %% [markdown]
# <a href="https://colab.research.google.com/github/plthiyagu/Personnel/blob/master/Extract_tabular_data_from_PDF_document_using_Camelot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "camelot-py[cv]"
# Out:
# ...
#      |████████████████████████████████| 51kB 1.6MB/s
# ...
#      |████████████████████████████████| 5.6MB 5.8MB/s
# ...
#      |████████████████████████████████| 81kB 7.5MB/s
# ...
#      |████████████████████████████████| 2.7MB 34.1MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61086 sha256=bcf0adf9461881de3d5bd2ed92945354bb732d894d8d6dfaa9df5deb80dd4c48
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
import camelot

# %%
# Syntax of the camelot.read_pdf function 
camelot.read_pdf(
    filepath,
    pages='1',
    password=None,
    flavor='lattice',
    suppress_stdout=False,
    layout_kwargs={},
    **kwargs,
)

# %%
filepath='https://raw.githubusercontent.com/plthiyagu/Personnel/master/Dataset/gst-revenue-collection-march2020.pdf'

# %%
tables2=camelot.read_pdf('gst-revenue-collection-march2020.pdf', flavor='stream', pages='0-3')
tables2
# Out:
# ...
# <TableList n=4>

# %%
tables2[2]
# Out:
# <Table shape=(23, 7)>

# %%
tables2[2].parsing_report
# Out:
# {'accuracy': 99.51, 'order': 1, 'page': 2, 'whitespace': 3.73}

# %%
df2=tables2[2].df
df2
# Out:
#                     0  ...       6
# 0                      ...
# 1               State  ...  Growth
# 2   Jammu and Kashmir  ...      6%
# 3    Himachal Pradesh  ...      5%
# 4              Punjab  ...      9%
# 5          Chandigarh  ...     12%
# 6         Uttarakhand  ...     -3%
# 7             Haryana  ...      8%
# 8               Delhi  ...     11%
# 9           Rajasthan  ...      7%
# 10      Uttar Pradesh  ...      6%
# 11              Bihar  ...     18%
# 12             Sikkim  ...     17%
# 13  Arunachal Pradesh  ...     46%
# 14           Nagaland  ...     40%
# 15            Manipur  ...     41%
# 16            Mizoram  ...     39%
# 17            Tripura  ...     22%
# 18          Meghalaya  ...     11%
# 19              Assam  ...     16%
# 20        West Bengal  ...      9%
# 21          Jharkhand  ...     -4%
# 22             Odisha  ...     10%
#
# [23 rows x 7 columns]

# %%
tables2[3]
tables2[3].parsing_report
# Out:
# {'accuracy': 100.0, 'order': 1, 'page': 3, 'whitespace': 9.29}

# %%
df3=tables2[3].df
df3
# Out:
#                          0       1       2     3         4         5     6
# 0             Chhattisgarh   2,143   2,093   -2%    22,932    24,160    5%
# 1           Madhya Pradesh   2,624   2,407   -8%    25,683    28,354   10%
# 2                  Gujarat   6,521   6,820    5%    73,440    78,923    7%
# 3            Daman and Diu     103      95   -8%     1,105     1,155    5%
# 4   Dadra and Nagar Haveli     174     169   -3%     1,718     1,810    5%
# 5              Maharashtra  15,596  15,002   -4%  1,70,289  1,85,917    9%
# 6                Karnataka   6,983   7,144    2%    78,763    83,408    6%
# 7                      Goa     389     316  -19%     4,103     4,280    4%
# 8              Lakshadweep       1       1   54%        20        20    2%
# 9                   Kerala   1,635   1,475  -10%    16,343    19,234   18%
# 10              Tamil Nadu   6,941   6,178  -11%    70,562    74,430    5%
# ...

# %%
df4=df2.append(df3)
df4
# Out:
#                          0  ...       6
# 0                           ...
# 1                    State  ...  Growth
# 2        Jammu and Kashmir  ...      6%
# 3         Himachal Pradesh  ...      5%
# 4                   Punjab  ...      9%
# 5               Chandigarh  ...     12%
# 6              Uttarakhand  ...     -3%
# 7                  Haryana  ...      8%
# 8                    Delhi  ...     11%
# 9                Rajasthan  ...      7%
# 10           Uttar Pradesh  ...      6%
# 11                   Bihar  ...     18%
# 12                  Sikkim  ...     17%
# 13       Arunachal Pradesh  ...     46%
# 14                Nagaland  ...     40%
# 15                 Manipur  ...     41%
# 16                 Mizoram  ...     39%
# 17                 Tripura  ...     22%
# 18               Meghalaya  ...     11%
# 19                   Assam  ...     16%
# 20             West Bengal  ...      9%
# 21               Jharkhand  ...     -4%
# 22                  Odisha  ...     10%
# ...

# %%
df5=df4[1:]
df5.head()
new_header = df5.iloc[0]
df5 = df5[1:]
df5.columns = new_header

# %%
df5.head()
# Out:
# 1              State Mar-19 Mar-20 Growth 2018-19 2019-20 Growth
# 2  Jammu and Kashmir    388    276   -29%   3,792   4,010     6%
# 3   Himachal Pradesh    660    596   -10%   7,593   7,960     5%
# 4             Punjab  1,166  1,181     1%  13,979  15,235     9%
# 5         Chandigarh    162    153    -5%   1,779   1,988    12%
# 6        Uttarakhand  1,451  1,195   -18%  15,150  14,722    -3%
