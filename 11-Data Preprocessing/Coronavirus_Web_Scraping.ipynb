# %%
from datetime import date
today=date.today()

d=today.strftime("%m-%d-%y")

# %%
cnn_url="https://www.cnn.com/world/live-news/coronavirus-pandemic-{}/index.html".format(d)

# %%
print(cnn_url)
# Out:
# https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html

# %%
from bs4 import BeautifulSoup
import requests

# %%
html= requests.get(cnn_url).text

# %%
soup = BeautifulSoup(html)
print(soup.title)
# Out:
# <title data-rh="true">Coronavirus pandemic: Live updates - CNN</title>

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
for link in soup.find_all("h2"):
    print("Headline : {}".format(link.text))
    for ent in nlp(link.text).ents: 
      print("\tText : {}, Entity : {}".format(ent.text, ent.label_))
# Out:
# Headline : What you need to know
# Headline : NY Federal Reserve scaling back emergency intervention into financial markets
# 	Text : NY Federal Reserve, Entity : ORG
# Headline : Treasury says 80 million people will receive stimulus payments this week
# 	Text : Treasury, Entity : ORG
# 	Text : 80 million, Entity : CARDINAL
# 	Text : this week, Entity : DATE
# Headline : ESPN asks commentators to take a 15% pay cut because of coronavirus
# 	Text : ESPN, Entity : ORG
# 	Text : 15%, Entity : PERCENT
# Headline : West Coast states make pact to work together on reopening based on health outcomes
# 	Text : West Coast, Entity : LOC
# Headline : US stocks end mixed
# 	Text : US, Entity : GPE
# Headline : New Jersey law school grads can temporarily practice law without taking the bar, court rules
# 	Text : New Jersey, Entity : GPE
# Headline : More than 17% of the New York police force is out sick
# 	Text : More than 17%, Entity : PERCENT
# 	Text : New York, Entity : GPE
# Headline : More than 130,000 unemployment claims filed in the last three weeks in Kansas, governor says
# 	Text : More than 130,000, Entity : CARDINAL
# 	Text : the last three weeks, Entity : DATE
# 	Text : Kansas, Entity : GPE
# Headline : Ford will start producing respirator masks and other equipment for health care workers
# 	Text : Ford, Entity : ORG

# %%
nbc_url='https://www.nbcnews.com/health/coronavirus'
cnbc_rss_url='https://www.cnbc.com/id/10000108/device/rss/rss.html'

# %%
urls=[cnn_url, nbc_url,cnbc_rss_url]
formats=['html.parser','html.parser','xml']
tags=['h2','h2','description']
website=['CNN', 'NBC','CNBC']

# %%
crawl_len=0
news_dict=[]
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content,formats[crawl_len])

    for link in soup.find_all(tags[crawl_len]):

      if(len(link.text.split(" ")) > 4):

        entities=[]

        entities=[(ent.text, ent.label_) for ent in nlp(link.text).ents]

        news_dict.append({'website':website[crawl_len],'url': url,'headline':link.text,'entities':entities})
    
    crawl_len=crawl_len+1

# %%
news_dict
# Out:
# [{'entities': [],
#   'headline': 'What you need to know',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [('Kansas', 'GPE'), ('4', 'CARDINAL')],
#   'headline': 'Kansas religious gathering tied to 4 coronavirus deaths, state officials say',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [('Today', 'DATE'), ('daily', 'DATE'), ('US', 'GPE')],
#   'headline': 'Today is the peak for daily deaths in the US, coronavirus model says',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [],
#   'headline': 'Pompeo: "There’ll be a time for recriminations" over the novel coronavirus',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [('Cuomo', 'ORG'), ('180', 'CARDINAL')],
#   'headline': 'Cuomo says federal government would need to "do a 180" to reopen states ',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [('Pentagon', 'ORG'), ('$415 million', 'MONEY'), ('N95', 'ORG')],
#   'headline': 'Pentagon awards $415 million contract to reuse N95 masks',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [('Colorado', 'GPE')],
#   'headline': 'Colorado governor says meat packing plant in his state will be closed for"as long as it takes" ',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [('Nearly 1,000', 'CARDINAL'), ('Washington', 'GPE')],
#   'headline': 'Nearly 1,000 prisoners in Washington state may be released early',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [('Connecticut', 'GPE'), ('Trump', 'LOC'), ('one', 'CARDINAL')],
#   'headline': 'Connecticut governor: Trump administration won\'t "try and mandate a one size fits all" on reopening states',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [('US', 'GPE'), ('750,000', 'CARDINAL'), ('South Korea', 'GPE')],
#   'headline': 'US to receive 750,000 coronavirus tests from South Korea',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-pandemic-04-13-20/index.html',
#   'website': 'CNN'},
#  {'entities': [('White House', 'ORG'), ('Trump', 'GPE'), ('Fauci', 'ORG')],
#   'headline': "White House says Trump won't fire Fauci after he retweeted remark saying it's 'time to fire' him",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Live Blog\xa0/ Latest news on the global pandemic',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('FDA', 'ORG')],
#   'headline': 'FDA clears first saliva test to diagnose coronavirus',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Coronavirus', 'ORG')],
#   'headline': 'Check your balance: Coronavirus stimulus money starts to flow into bank accounts',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('325', 'CARDINAL')],
#   'headline': 'Dow closes down 325 points as investors brace for brutal earnings week',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "Police chief on leave for alleged remarks on gay cop's COVID-19 death",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('White House', 'ORG'), ('Trump', 'GPE'), ('Fauci', 'ORG')],
#   'headline': "White House says Trump won't fire Fauci over coronavirus comments",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Sailor on USS Theodore Roosevelt dies after contracting coronavirus',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Stanley Chera', 'PERSON')],
#   'headline': 'Trump friend Stanley Chera dies from coronavirus complications',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Amazon', 'ORG')],
#   'headline': 'Amazon stops accepting new online grocery customers amid surging demand',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Michelle Obama', 'PERSON'), ('2020', 'DATE')],
#   'headline': 'Michelle Obama group backs expanding voting options for 2020 amid pandemic',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Pelosi', 'ORG'), ('Schumer', 'PERSON')],
#   'headline': "Pelosi, Schumer say they're not backing down on coronavirus relief demands",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('George Stephanopoulos', 'PERSON')],
#   'headline': "'Good Morning America' anchor George Stephanopoulos tests positive for coronavirus",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('GOP', 'ORG'), ('U.S.', 'GPE')],
#   'headline': "GOP governor: Reopening the U.S. will be 'just as tough, if not tougher' than start of coronavirus outbreak",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('CDC', 'ORG')],
#   'headline': 'Swift coronavirus testing needed before reopening country, CDC director says',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "Fauci: Earlier social distancing measures 'obviously' would have saved more lives",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('America', 'GPE')],
#   'headline': "Starving, angry and cannibalistic: America's rats are getting desperate amid coronavirus pandemic",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('billions', 'CARDINAL')],
#   'headline': 'Unapproved online lenders solicit borrowers for billions in small business loans',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('May', 'DATE')],
#   'headline': "Trump eager to restart economy by May as he weighs 'toughest' decision of his presidency",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('OPEC', 'ORG')],
#   'headline': 'OPEC and allies agree largest cut in oil output in history',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('French', 'NORP'), ('the United States', 'GPE')],
#   'headline': "French family's road trip across the United States takes a twist due to coronavirus",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Los Angeles County', 'GPE')],
#   'headline': 'Los Angeles County launches large-scale COVID-19 antibody testing',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('U.K.', 'GPE'), ('Boris Johnson', 'PERSON')],
#   'headline': "U.K.'s Boris Johnson leaves hospital after personal COVID-19 battle",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Coronavirus', 'ORG'), ('Latino', 'PERSON')],
#   'headline': "Coronavirus could 'decimate' Latino wealth, hammered by the Great Recession",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('British', 'NORP'),
#    ('Tim Brooke-Taylor', 'PERSON'),
#    ('79', 'CARDINAL')],
#   'headline': 'British comedian Tim Brooke-Taylor dies of coronavirus at 79',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Pope Francis', 'PERSON'), ('Easter', 'PERSON')],
#   'headline': 'Pope Francis gives Easter address to an empty basilica',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Tom Hanks', 'PERSON')],
#   'headline': "Live from their bedrooms, it's 'SNL'! Tom Hanks returns to host remote episode",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('one', 'CARDINAL')],
#   'headline': 'Race is just one factor in COVID-19 risk',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "Despite encouraging signs, coronavirus is 'advancing' worldwide, WHO envoy warns",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "Doctor reunites with wife and new baby after work with coronavirus 'dirty team'",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "The woman leading COVID-19 vaccine trials is 'not your average pocket-protector scientist'",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('One year', 'DATE')],
#   'headline': 'One year waiting: Transgender man who wants to enlist cites coronavirus urgency',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Vietnamese', 'NORP'), ('thousands', 'CARDINAL')],
#   'headline': 'Vietnamese-owned nail salons donate thousands of masks, gloves, more to hospitals',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "'Cannonball' coast-to-coast drive record set amid virus shutdown",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Six', 'CARDINAL'), ('California', 'GPE')],
#   'headline': 'Six people shot at California house party that violated stay-at-home order',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('U.S.', 'GPE'), ('Trump', 'PERSON')],
#   'headline': "U.S. now leads world in deaths, day after Trump announces 'opening our country' task force",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Hospital workers on front lines of coronavirus fight find their tires slashed',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Man accused of scamming pizza restaurants with fake large orders for police',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Michael Avenatti', 'PERSON'), ('New York', 'GPE')],
#   'headline': 'Michael Avenatti released from New York jail over coronavirus concerns',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('NYC', 'ORG'), ('year', 'DATE'), ('Cuomo', 'ORG')],
#   'headline': 'NYC mayor says schools will stay closed rest of year, Cuomo says not so fast',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Easter', 'FAC')],
#   'headline': 'Priests find new ways to celebrate Easter in the age of coronavirus',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Cuba', 'GPE'), ('U.S.', 'GPE')],
#   'headline': "Cuba, U.S. dispute embargo's role in blocking coronavirus supplies",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Chicago', 'GPE')],
#   'headline': 'Chicago mayor defends hairstylist visit amid coronavirus outbreak',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('British', 'NORP'), ('World War II', 'EVENT')],
#   'headline': 'British bakers reintroduce World War II bread in coronavirus fight',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "With nowhere for women to go wax our lips or brows, let's just be hairy together",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Cannabis', 'ORG')],
#   'headline': 'No federal relief: Cannabis businesses cry for help as coronavirus batters industry',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Amish', 'NORP')],
#   'headline': 'Authorities work to keep Amish communities informed amid coronavirus pandemic',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "A 'nightmare' scenario on the rise with coronavirus: Dying alone",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Philadelphia', 'GPE')],
#   'headline': 'Is Philadelphia the next coronavirus hot spot? Maybe not.',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "Everyone's cooking during quarantine. And finally, so am I.",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Kentucky', 'GPE'), ('Easter', 'PRODUCT')],
#   'headline': 'Kentucky gov. announces mandatory quarantine for anyone who attends Easter services',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Texas', 'GPE')],
#   'headline': 'Appeals court lifts part of order blocking Texas abortion ban',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Trump', 'LOC')],
#   'headline': 'Behind closed doors, Trump’s coronavirus task force boosts industry and sows confusion',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('10', 'CARDINAL')],
#   'headline': "'I'm the one hoarding toilet paper': 10 anonymous confessions in the time of coronavirus",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('NBC News', 'ORG')],
#   'headline': 'Coronavirus pandemic: An NBC News special report ',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('NBC News', 'ORG'), ("Coronavirus Pandemic'", 'ORG')],
#   'headline': "NBC News special report: 'Coronavirus Pandemic'",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Coronavirus: What you need to know',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [("The Red Zone'", 'ORG'), ('NBC News', 'ORG')],
#   'headline': "'Into The Red Zone': An NBC News NOW documentary ",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Photos capture empty cities across the globe',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('New Yorkers', 'NORP')],
#   'headline': 'New Yorkers are giving nightly ovations to health workers. These are their portraits',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Portrait of a neighborhood under lockdown',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Nebraska', 'GPE')],
#   'headline': "In Nebraska, meat plant workers are afraid to go to work — but can't afford to stay home",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Coronavirus', 'ORG'), ('100', 'CARDINAL')],
#   'headline': 'Coronavirus live updates: Global death toll passes 100K',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Experimental drug may help very sick coronavirus patients, early research suggests',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Pastor caves after defying coronavirus rules',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Thousands', 'CARDINAL'), ('U.S.', 'GPE')],
#   'headline': "Thousands have died in nursing homes around the U.S. But the federal gov't isn't tracking them.",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Race rises to the forefront for activists in the coronavirus pandemic',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Groups', 'ORG')],
#   'headline': 'Groups mobilize to feed health care workers',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Companies struggling to retain staff face tough choice: Slash 401(k) plans, cut salaries or furlough workers?',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('French', 'NORP'), ('U.K.', 'GPE')],
#   'headline': 'French police turn away private jet passengers escaping U.K. coronavirus lockdown',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Apple', 'ORG'), ('Google', 'ORG')],
#   'headline': "Apple and Google say they'll work together to trace spread of coronavirus via smartphones",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Trump', 'PRODUCT')],
#   'headline': 'Trump makes bogus claims about mail-in vote fraud. Here are the facts.',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Latest news for health care. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('yesterday', 'DATE'),
#    ('nearly 4%', 'PERCENT'),
#    ('New Jersey', 'GPE'),
#    ('Murphy', 'PERSON')],
#   'headline': 'The increase in new cases reported since yesterday was nearly 4%, the lowest rise New Jersey has reported since the coronavirus outbreak began, Murphy said.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('months', 'DATE'),
#    ('German', 'NORP'),
#    ('Jens Spahn', 'PERSON')],
#   'headline': '"All the measures we have taken like keeping distance, wearing masks, no parties ... are definitely measures that need to be there in place for months to come," German Health Minister Jens Spahn said.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Monday', 'DATE'), ('daily', 'DATE')],
#   'headline': 'Members of the coronavirus task force are expected to hold a press briefing Monday, in what has become a daily affair amid signs that the curve is flattening in some hard-hit areas.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('The Food and Drug Administration', 'ORG'),
#    ('Rutgers University', 'ORG'),
#    ('New Jersey', 'GPE')],
#   'headline': 'The Food and Drug Administration granted emergency use authorization for a coronavirus test relying on saliva samples developed by a Rutgers University-backed entity, the New Jersey college announced.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('New Jersey', 'GPE'),
#    ('Phil Murphy', 'PERSON'),
#    ('daily', 'DATE'),
#    ('more than 61,800', 'CARDINAL'),
#    ('Monday', 'DATE')],
#   'headline': 'New Jersey Gov. Phil Murphy is holding his daily press conference on the Covid-19 outbreak, which has infected more than 61,800 people as of Monday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Treasury Department', 'ORG')],
#   'headline': "Treasury Department requests to airlines for coronavirus aid are a preview of what's to come for other industries.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Cuomo', 'ORG'), ('Donald Trump', 'PERSON')],
#   'headline': 'The governors, led by Cuomo, announced the coronavirus group hours after President Donald Trump claimed in a tweet that he, not state leaders, has the power to decide when to "open up" country.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Earlier Monday', 'DATE'),
#    ('Cuomo', 'ORG'),
#    ('New York', 'GPE')],
#   'headline': 'Earlier Monday, Cuomo said New York is "controlling the spread" of the coronavirus, and it appears that "the worst is over ... if we continue to be smart going forward."',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Mike Ryan', 'PERSON'), ('WHO', 'ORG'), ('Monday', 'DATE')],
#   'headline': '"With regards to recovery and then reinfection, I believe we do not have the answers to that. That is an unknown," Dr. Mike Ryan, executive director of WHO\'s emergencies program, said at a press conference Monday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Andrew Cuomo', 'PERSON'),
#    ('New York', 'GPE'),
#    ('10,000', 'CARDINAL')],
#   'headline': 'Gov. Andrew Cuomo said New York is "controlling the spread" of the coronavirus. He also said the state\'s death toll from Covid-19 has topped 10,000.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Adhanom Ghebreyesus', 'ORG'), ('Monday', 'DATE')],
#   'headline': '"While Covid-19 accelerates very fast, it decelerates much more slowly. In other words, the way down is much slower than the way up," WHO Director-General Tedros Adhanom Ghebreyesus said at a press conference Monday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Tony Wilkinson', 'PERSON'),
#    ('the National Association of Guaranteed Government Lenders', 'ORG')],
#   'headline': '"We have mostly undisbursed loans at this time" said Tony Wilkinson, president of the National Association of Guaranteed Government Lenders.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('New York', 'GPE'),
#    ('Andrew Cuomo', 'PERSON'),
#    ('more than 190200', 'CARDINAL'),
#    ('Monday', 'DATE'),
#    ('morning', 'TIME')],
#   'headline': 'New York Gov. Andrew Cuomo is holding his daily press conference on the Covid-19 outbreak, which has infected more than 190200 people in the state as of Monday morning.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [],
#   'headline': 'WHO is holding a briefing on the Covid-19 pandemic.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('New York City', 'GPE'),
#    ('Bill de Blasio', 'PERSON'),
#    ('Monday', 'DATE')],
#   'headline': 'New York City Mayor Bill de Blasio is holding a press conference Monday to update the public on the coronavirus outbreak.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Republican', 'NORP')],
#   'headline': 'The Republican billionaire praised the health-care industry, public service workers and drug companies but bashed the media regarding the coronavirus.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('de Blasio', 'PERSON'),
#    ('last week', 'DATE'),
#    ('June', 'DATE')],
#   'headline': 'Despite the appearance that the outbreak has peaked, de Blasio warned last week that social distancing restrictions may need to be extended until June to prevent the outbreak from resurging.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('nearly 2 million', 'CARDINAL'),
#    ('Monday', 'DATE'),
#    ('at least 114,979', 'CARDINAL')],
#   'headline': 'Covid-19 has infected nearly 2 million people around the world as Monday, killing at least 114,979 people.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('South African', 'NORP'), ('Cyril Ramaphosa', 'PERSON')],
#   'headline': 'South African President Cyril Ramaphosa has vowed to take action after a wave of gender-based violence, robbery and vandalism across the country.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Monday', 'DATE'), ('1974', 'DATE')],
#   'headline': "Stock futures were lower Monday after the S&P 500's best week since 1974.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Spain', 'GPE'), ('Monday', 'DATE')],
#   'headline': 'Construction and factory workers in Spain return to work on Monday as the government lifts some of the most stringent lockdown measures, but opposition parties caution against a relaxation of the rules.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('The World Health Organization', 'ORG'),
#    ('Donald Trump', 'PERSON'),
#    ('China', 'GPE'),
#    ('Taiwan', 'GPE')],
#   'headline': "The World Health Organization has come under intense scrutiny for its handling of the coronavirus pandemic with President Donald Trump's administration, China and Taiwan locked in a tussle of words.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Trump', 'PERSON'), ('China', 'GPE'), ('U.S.', 'GPE')],
#   'headline': "The Trump administration's tariffs on imported medical equipment, particularly from China, have added to the struggle in the U.S.'s fight against the coronavirus outbreak.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Russia', 'GPE'),
#    ('2,558', 'CARDINAL'),
#    ('Monday', 'DATE'),
#    ('Spain', 'GPE')],
#   'headline': 'Russia reported 2,558 new infections on Monday while in Spain, the government is lifting some lockdown measures.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Kashkari', 'ORG'),
#    ('days', 'DATE'),
#    ('the Labor Department', 'ORG'),
#    ('6.6 million', 'CARDINAL'),
#    ('Americans', 'NORP'),
#    ('first', 'ORDINAL'),
#    ('the past week', 'DATE')],
#   'headline': "Kashkari's comments came days after the Labor Department reported that another 6.6 million Americans filed first-time unemployment claims in the past week.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Fauci', 'ORG'),
#    ('less than a day', 'DATE'),
#    ('U.S.', 'GPE'),
#    ('more than 20,000', 'CARDINAL'),
#    ('Italy', 'GPE')],
#   'headline': "Fauci's hopeful remarks came less than a day after the U.S. counted more than 20,000 deaths from the disease, surpassing Italy as the nation with the highest number of recorded deaths in the world.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('a week', 'DATE'),
#    ('London', 'GPE'),
#    ("St. Thomas'", 'GPE'),
#    ('three days', 'DATE')],
#   'headline': "The prime minister spent a week in London's St. Thomas' hospital with Covid-19, three days of which were in intensive care.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Russia', 'GPE'),
#    ('daily', 'DATE'),
#    ('Sunday', 'DATE'),
#    ('2,186', 'CARDINAL'),
#    ('15,770', 'CARDINAL')],
#   'headline': "Russia reported its biggest daily jump in new coronaviruses cases so far on Sunday at 2,186, bringing the country's total confirmed cases to 15,770.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Donald Trump', 'PERSON'),
#    ('Wyoming', 'GPE'),
#    ('Saturday', 'DATE'),
#    ('22 days', 'DATE'),
#    ('first', 'ORDINAL'),
#    ('New York', 'GPE')],
#   'headline': 'President Donald Trump approved a disaster declaration for Wyoming on Saturday, which comes 22 days after the first disaster declaration in New York, the epicenter of the coronavirus.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'}]

# %%
import pandas as pd
new_df = pd.DataFrame(news_dict)

# %%
pd.set_option('max_colwidth', 800)
new_df.head(20)
# Out:
#    website  ...                                              entities
# 0      CNN  ...                                                    []
# 1      CNN  ...                        [(Kansas, GPE), (4, CARDINAL)]
# 2      CNN  ...             [(Today, DATE), (daily, DATE), (US, GPE)]
# 3      CNN  ...                                                    []
# 4      CNN  ...                       [(Cuomo, ORG), (180, CARDINAL)]
# 5      CNN  ...  [(Pentagon, ORG), ($415 million, MONEY), (N95, ORG)]
# 6      CNN  ...                                     [(Colorado, GPE)]
# 7      CNN  ...         [(Nearly 1,000, CARDINAL), (Washington, GPE)]
# 8      CNN  ...   [(Connecticut, GPE), (Trump, LOC), (one, CARDINAL)]
# 9      CNN  ...  [(US, GPE), (750,000, CARDINAL), (South Korea, GPE)]
# 10     NBC  ...      [(White House, ORG), (Trump, GPE), (Fauci, ORG)]
# 11     NBC  ...                                                    []
# 12     NBC  ...                                          [(FDA, ORG)]
# 13     NBC  ...                                  [(Coronavirus, ORG)]
# 14     NBC  ...                                     [(325, CARDINAL)]
# 15     NBC  ...                                                    []
# 16     NBC  ...      [(White House, ORG), (Trump, GPE), (Fauci, ORG)]
# 17     NBC  ...                                                    []
# 18     NBC  ...                             [(Stanley Chera, PERSON)]
# 19     NBC  ...                                       [(Amazon, ORG)]
#
# [20 rows x 4 columns]

# %%
news_final_df = pd.concat([new_df[['website','url','headline']],new_df['entities'].apply(pd.Series)],axis=1)

# %%
news_final_df.head()
# Out:
#   website  ...    6
# 0     CNN  ...  NaN
# 1     CNN  ...  NaN
# 2     CNN  ...  NaN
# 3     CNN  ...  NaN
# 4     CNN  ...  NaN
#
# [5 rows x 10 columns]

# %%
new_df.to_csv("web_scapping.csv")
