# %% [markdown]
# <a href="https://colab.research.google.com/github/plthiyagu/Personnel/blob/master/Data_Collection_for_Image_Classification_Microsoft_Bing_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader
# Out:
# Requirement already satisfied: bing-image-downloader in /usr/local/lib/python3.6/dist-packages (1.0.4)

# %%
# !mkdir images
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
from bing_image_downloader import downloader
downloader.download("elephant in africa",limit=5,output_dir='images',adult_filter_off=True,force_replace=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://c402277.ssl.cf1.rackcdn.com/photos/12637/images/magazine_medium/Medium_WW22456.jpg?1477667080
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://news.nationalgeographic.com/content/dam/news/photos/000/306/30651.ngsversion.1421960098780.adapt.1900.1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://messagenote.com/wp-content/uploads/2011/05/Africa-Elephants.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Loxodonta_africana_-_old_bull_%28Ngorongoro%2C_2009%29.jpg/1200px-Loxodonta_africana_-_old_bull_%28Ngorongoro%2C_2009%29.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.ytimg.com/vi/5EL8-Pra4tE/maxresdefault.jpg
# [%] File Downloaded !

# %%
downloader.download("kangaroo in australia",limit=5,output_dir='images',adult_filter_off=True,force_replace=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://s.yimg.com/ny/api/res/1.2/a2DVZFx1BCmeraT.UEcnOQ--~A/YXBwaWQ9aGlnaGxhbmRlcjtzbT0xO3c9ODAw/https://media.zenfs.com/en/pa_viral_news_uk_120/635637949f3fad534615137975e70f0e
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images.news18.com/ibnlive/uploads/2020/07/1595426763_kangaroo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.newsapi.com.au/image/v1/c9c38750fa3fbd99d79a0b732ef5378f
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.cnn.com/cnnnext/dam/assets/200722145446-qantas-flight-path-kangaroo-logo-super-tease.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2018/08/15/Pictures/red-kangaroo-outback-grasslands-in-the-australian_5cd01cb2-a092-11e8-9345-8d51f8ed9678.jpg
# [%] File Downloaded !

# %%
# !ls images/ -alrt
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jul 29 20:34  ..
# drwxr-xr-x 2 root root 4096 Jul 29 20:36 'elephant in africa'
# drwxr-xr-x 4 root root 4096 Jul 29 20:38  .
# drwxr-xr-x 2 root root 4096 Jul 29 20:38 'kangaroo in australia'

# %%
# !ls images
# Out:
# 'elephant in africa'  'kangaroo in australia'

# %%
# !ls 'images'/'elephant in africa'
# Out:
# Image_1.jpg  Image_2.jpg  Image_3.jpg  Image_4.jpg  Image_5.jpg

# %%
# !ls images/kangaroo\ in\ australia
# Out:
# Image_1.jpg  Image_2.jpg  Image_3.jpg  Image_4.jpg  Image_5.jpg

# %%
from IPython.display import  Image
Image("images/elephant in africa/Image_5.jpg")

# %%
from IPython.display import  Image
Image("images/kangaroo in australia/Image_5.jpg")

# %%
from six import BytesIO
from PIL import Image
import numpy as np
import glob
import os

import matplotlib
import matplotlib.pyplot as plt

# %%
def load_image_into_numpy_array(path):
  img_data= open(path,'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width,im_height) = image.size
  return np.array(image.getdata()).reshape((im_height,im_width,3)).astype(np.uintc)

# %%
elephant_image_path="/content/images/elephant in africa/*"
elephant_images_np=[]
for iname in glob.glob(elephant_image_path):
  elephant_images_np.append(load_image_into_numpy_array(iname))
print(len(elephant_images_np))
# Out:
# 5

# %%
plt.rcParams['figure.figsize'] = [14, 7]

for idx,elephant_image_np in enumerate(elephant_images_np):
  plt.subplot(2,3,idx+1)
  plt.imshow(elephant_image_np)
plt.show()
