# %% [markdown]
# <a href="https://colab.research.google.com/github/plthiyagu/AI-Engineering/blob/master/12-Vision%20and%20Image/Some_Advanced_OpenCV_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
# !wget https://raw.githubusercontent.com/plthiyagu/Personnel/master/Dataset/Images/cd0c13629f217c1ab72c61d0664b3f99.jpg
# Out:
# --2021-07-27 19:52:41--  https://raw.githubusercontent.com/plthiyagu/Personnel/master/Dataset/Images/cd0c13629f217c1ab72c61d0664b3f99.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40034 (39K) [image/jpeg]
# Saving to: ‘cd0c13629f217c1ab72c61d0664b3f99.jpg’
#
# cd0c13629f217c1ab72 100%[===================>]  39.10K  --.-KB/s    in 0.01s
#
# 2021-07-27 19:52:41 (3.72 MB/s) - ‘cd0c13629f217c1ab72c61d0664b3f99.jpg’ saved [40034/40034]

# %%
 # load it in GRAYSCALE color mode...
 image = cv2.imread("""cd0c13629f217c1ab72c61d0664b3f99.jpg""", 0)
cv2_imshow(image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=451x268 at 0x7F891E748950>

# %%
print(image.shape)
# Out:
# (268, 451)

# %%
print("The Image Height Is: %d Pixels"%(image.shape[0]))
print("The Image Width Is: %d Pixels"%(image.shape[1]))
# Out:
# The Image Height Is: 268 Pixels
# The Image Width Is: 451 Pixels

# %%
import cv2
# re-load it in color mode...
image = cv2.imread("cd0c13629f217c1ab72c61d0664b3f99.jpg", cv2.IMREAD_COLOR)
cv2_imshow( image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=451x268 at 0x7F891E04D550>

# %%
print(image.shape)
print("Image Height: %d Pixels"%(image.shape[0]))
print("Image Width: %d Pixels"%(image.shape[1]))
print("Number Of Color Channels: %d "%(image.shape[2]))
# Out:
# (268, 451, 3)
# Image Height: 268 Pixels
# Image Width: 451 Pixels
# Number Of Color Channels: 3

# %% [markdown]
# Learning How to Resize an Image

# %%
import cv2
# load the image in a GRAYSCALE format
image = cv2.imread("cd0c13629f217c1ab72c61d0664b3f99.jpg", cv2.IMREAD_GRAYSCALE)
cv2_imshow(image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=451x268 at 0x7F891E040E90>

# %%
 # resize the image to be pixel dimensions 350 by 350
 resized_image = cv2.resize(image, dsize=(350, 350))
 cv2_imshow(resized_image)
 cv2.waitKey()
 cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=350x350 at 0x7F891E037490>
