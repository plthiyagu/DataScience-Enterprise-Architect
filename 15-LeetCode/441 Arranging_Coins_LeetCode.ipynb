# %% [markdown]
# <a href="https://colab.research.google.com/github/plthiyagu/AI-Engineering/blob/master/22-LeetCode/Arranging_Coins_LeetCode_441.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
def arrangeCoins( n):
    """
    :type n: int
    :rtype: int
    """
    return int((math.sqrt(8*n+1)-1) / 2)

# %%
n=5
arrangeCoins( n)
# Out:
# 2
