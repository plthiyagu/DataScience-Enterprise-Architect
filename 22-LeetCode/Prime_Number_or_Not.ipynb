# %% [markdown]
# <a href="https://colab.research.google.com/github/plthiyagu/Personnel/blob/master/Prime_Number_or_Not.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def prime(num):
  if(num>1):
    for i in range(2,num):
      if i% 2 ==0:
        print("number is not prime",i)
      else:
        print("number is prime",i)

  else:
    print("number not prime")

num=407
prime(num)
# Out:
# number is not prime 2
# number is prime 3
# number is not prime 4
# number is prime 5
# number is not prime 6
# number is prime 7
# number is not prime 8
# number is prime 9
# number is not prime 10
# number is prime 11
# number is not prime 12
# number is prime 13
# number is not prime 14
# number is prime 15
# number is not prime 16
# number is prime 17
# number is not prime 18
# number is prime 19
# number is not prime 20
# number is prime 21
# number is not prime 22
# number is prime 23
# number is not prime 24
# number is prime 25
# number is not prime 26
# number is prime 27
# number is not prime 28
# number is prime 29
# number is not prime 30
# number is prime 31
# number is not prime 32
# number is prime 33
# number is not prime 34
# number is prime 35
# number is not prime 36
# number is prime 37
# number is not prime 38
# number is prime 39
# number is not prime 40
# number is prime 41
# number is not prime 42
# number is prime 43
# number is not prime 44
# ...
