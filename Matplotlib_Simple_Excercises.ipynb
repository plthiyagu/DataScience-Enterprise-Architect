# %% [markdown]
# <a href="https://colab.research.google.com/github/plthiyagu/Personnel/blob/master/Matplotlib_Simple_Excercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot

# %%
X,y= make_regression(n_samples=100,n_features=1,noise=20)
pyplot.scatter(X,y)
pyplot.show()

# %%
import matplotlib.pyplot as plt


values=[10,30,44,22]
languages=["Java","C++","Python","Go"]

plt.pie(values,labels= languages,autopct='%.1f%%')
plt.title("Favorite Programming Language")
plt.show()
