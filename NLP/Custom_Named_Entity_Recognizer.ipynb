# %% [markdown]
# <a href="https://colab.research.google.com/github/plthiyagu/Personnel/blob/master/Custom_Named_Entity_Recognizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
nlp =spacy.load('en_core_web_sm')
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %%
doc = nlp("Australia wants to force  Facebook and Google to pay media companies for news")

# %%
for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)
# Out:
# Australia 0 9 GPE
# Facebook and Google 26 45 ORG

# %%
doc = nlp("I do not have money to pay my credit card account")

# %%
for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)

# %%
doc = nlp("what is the processto open  an new savings account")

# %%
for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)

# %%
train= [
    ("Money transfer from my checking account is not working",{"entities":[(6,13,"ACTIVITY"),(23,39,'PRODUCT')]}),
    ("I want to check balance in my savings Account",{"entities":[(16,23,"ACTIVITY"),(30,45,'PRODUCT')]}),
    ("I suspect fraud in my crdit card account",{"entities":[(12,17,"ACTIVITY"),(24,35,'PRODUCT')]}),
    ("I am here for opening a new savings account",{"entities":[(14,21,"ACTIVITY"),(28,43,'PRODUCT')]}),
    ("Your mortgage is in delinquent status",{"entities":[(20,30,"ACTIVITY"),(5,13,'PRODUCT')]}),
    ("Your credit card is in past due status",{"entities":[(23,31,"ACTIVITY"),(5,16,'PRODUCT')]}),
    ("My loan account is still not approved and funded",{"entities":[(25,37,"ACTIVITY"),(3,15,'PRODUCT'),(42,48,'PRODUCT')]}),
    ("How do i open a new loan account",{"entities":[(9,13,"ACTIVITY"),(20,32,'PRODUCT')]}),
    ("What are the changes on Investment Account",{"entities":[(9,13,"ACTIVITY"),(20,32,'PRODUCT')]}),
    ("Can you explain late charges on my credit card",{"entities":[(21,28,"ACTIVITY"),(35,46,'PRODUCT')]}),
    ("I want to open a new loan account",{"entities":[(10,14,"ACTIVITY"),(21,33,'PRODUCT')]}),
    ("Can you help updating payment on my credit card",{"entities":[(22,29,"ACTIVITY"),(36,47,'PRODUCT')]}),
    ("When is the paymnet due date on my card ",{"entities":[(12,19,"ACTIVITY"),(35,39,'PRODUCT')]})
]

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %%
ner=nlp.get_pipe("ner")

# %%
for _, annotations in train:
  for ent in annotations.get("entities"):
    ner.add_label(ent[2])

# %%
disable_pipes=[pipe for pipe in nlp.pipe_names if pipe != 'ner']

# %%
import random
from spacy.util import minibatch,compounding
from pathlib import Path


with nlp.disable_pipes(*disable_pipes):
  optimizer= nlp.resume_training()


  for iteration in range(100):
    random.shuffle(train)
    losses= {}

    batches= minibatch(train, size= compounding(1.0,4.0,1.001))
    for batch in batches:
      text,annotation= zip(*batch)
      nlp.update(
          text,
          annotation,
          drop=0.5,
          losses=losses,
          sgd=optimizer
      )
      print("Losses",losses)
# Out:
# Losses {'ner': 10.022269214267627}
# Losses {'ner': 17.526580012735735}
# Losses {'ner': 23.646334192116328}
# Losses {'ner': 32.15572731506573}
# Losses {'ner': 39.42603295738546}
# Losses {'ner': 49.11889620207704}
# Losses {'ner': 57.57232117364957}
# Losses {'ner': 64.0319842353657}
# Losses {'ner': 74.23511126052664}
# Losses {'ner': 79.21992725110373}
# Losses {'ner': 88.28724692294314}
# Losses {'ner': 96.26807856195312}
# Losses {'ner': 100.38502527645953}
# Losses {'ner': 5.0083999020571355}
# Losses {'ner': 12.456404335690383}
# Losses {'ner': 19.447623031971116}
# Losses {'ner': 26.743807134035332}
# Losses {'ner': 31.766034017076517}
# Losses {'ner': 42.33044839905742}
# Losses {'ner': 51.80873639953702}
# Losses {'ner': 58.63711036582267}
# Losses {'ner': 66.7248705597946}
# Losses {'ner': 73.16592570164963}
# Losses {'ner': 82.15701845058962}
# Losses {'ner': 87.50842901799669}
# Losses {'ner': 95.09320845867032}
# Losses {'ner': 6.890866517182985}
# Losses {'ner': 16.794447344581386}
# Losses {'ner': 28.92998926047494}
# Losses {'ner': 41.78895801756789}
# Losses {'ner': 49.24203120728498}
# Losses {'ner': 57.80711668820595}
# Losses {'ner': 64.1693521057955}
# Losses {'ner': 71.05082894083012}
# Losses {'ner': 80.16140865029433}
# Losses {'ner': 88.48391258012657}
# Losses {'ner': 96.61882506445204}
# Losses {'ner': 110.10641940072333}
# Losses {'ner': 116.84757040199565}
# Losses {'ner': 8.990543330553919}
# Losses {'ner': 17.77414176426828}
# Losses {'ner': 23.716566904946376}
# Losses {'ner': 26.757457965435606}
# Losses {'ner': 33.78257371125983}
# Losses {'ner': 44.723916765435206}
# Losses {'ner': 54.32117571182789}
# Losses {'ner': 59.923161669898036}
# Losses {'ner': 65.36452357567214}
# Losses {'ner': 73.60533769152426}
# Losses {'ner': 80.02653501977511}
# Losses {'ner': 88.98413644780703}
# Losses {'ner': 96.22032253493853}
# Losses {'ner': 9.231200536480173}
# Losses {'ner': 19.560453256359324}
# Losses {'ner': 29.028176663210616}
# Losses {'ner': 32.57529602909926}
# Losses {'ner': 44.7075392116094}
# Losses {'ner': 52.45541067386512}
# Losses {'ner': 61.72143442241941}
# Losses {'ner': 69.05189714638982}
# Losses {'ner': 76.58057529164944}
# Losses {'ner': 84.54633288516197}
# Losses {'ner': 95.05863021372352}
# Losses {'ner': 99.8378771772841}
# Losses {'ner': 107.39651098160539}
# Losses {'ner': 7.959065122529864}
# Losses {'ner': 15.601945845410228}
# Losses {'ner': 23.388412090484053}
# Losses {'ner': 29.541898163501173}
# Losses {'ner': 37.843381526414305}
# Losses {'ner': 45.17843274248298}
# Losses {'ner': 53.119745144969784}
# Losses {'ner': 63.23281874728855}
# Losses {'ner': 70.83244496805128}
# Losses {'ner': 80.26874020171817}
# Losses {'ner': 86.1415879674023}
# Losses {'ner': 92.1888514807215}
# Losses {'ner': 96.67513686686289}
# Losses {'ner': 7.470815360546112}
# Losses {'ner': 16.492149144411087}
# Losses {'ner': 24.32624070974998}
# Losses {'ner': 31.490874266950414}
# Losses {'ner': 39.76055833580904}
# Losses {'ner': 46.84438236515871}
# Losses {'ner': 54.80334614675394}
# Losses {'ner': 60.522877405322106}
# Losses {'ner': 70.5178486974155}
# Losses {'ner': 77.73414466243139}
# Losses {'ner': 84.7959954076623}
# Losses {'ner': 92.52392286892882}
# Losses {'ner': 98.29109833475104}
# Losses {'ner': 6.333091979846358}
# Losses {'ner': 13.522576531395316}
# Losses {'ner': 22.375290066935122}
# Losses {'ner': 28.479616374708712}
# Losses {'ner': 36.00065701175481}
# Losses {'ner': 42.08480682363734}
# Losses {'ner': 44.87061865394935}
# Losses {'ner': 51.221095758955926}
# Losses {'ner': 58.88806937960908}
# Losses {'ner': 67.82644142163917}
# Losses {'ner': 75.49328308505937}
# Losses {'ner': 83.81630494398996}
# Losses {'ner': 91.98794811172411}
# Losses {'ner': 6.842661872506142}
# Losses {'ner': 14.449271485209465}
# Losses {'ner': 19.95534172654152}
# Losses {'ner': 28.850246518850327}
# Losses {'ner': 33.71007188037038}
# Losses {'ner': 42.216199327260256}
# Losses {'ner': 49.70284977927804}
# Losses {'ner': 53.818938102573156}
# Losses {'ner': 57.89421946310904}
# Losses {'ner': 66.7724020233145}
# Losses {'ner': 75.15278859194794}
# Losses {'ner': 80.99078824315646}
# Losses {'ner': 88.72658777926543}
# Losses {'ner': 3.9248984355464387}
# Losses {'ner': 7.7539735296260375}
# Losses {'ner': 15.023474092547204}
# Losses {'ner': 20.39756814292481}
# Losses {'ner': 25.545203774188067}
# Losses {'ner': 34.90495428345015}
# Losses {'ner': 41.648173305157925}
# Losses {'ner': 51.63055954403093}
# Losses {'ner': 59.6473627454957}
# Losses {'ner': 67.76195333072748}
# Losses {'ner': 75.28347912350502}
# Losses {'ner': 80.82727791940626}
# Losses {'ner': 90.05654059922155}
# Losses {'ner': 7.540592864155769}
# Losses {'ner': 15.157632565125823}
# Losses {'ner': 20.828539113514125}
# Losses {'ner': 27.068631852278486}
# Losses {'ner': 35.71199827850796}
# Losses {'ner': 42.87158117140643}
# Losses {'ner': 49.82498185406439}
# Losses {'ner': 55.927879008231685}
# Losses {'ner': 61.9523702248116}
# Losses {'ner': 68.41607507440494}
# Losses {'ner': 76.38085415336536}
# Losses {'ner': 84.5996244524722}
# Losses {'ner': 90.49500675621675}
# Losses {'ner': 9.26609855890274}
# Losses {'ner': 16.78107639402151}
# Losses {'ner': 21.169325198978186}
# Losses {'ner': 24.202232051538886}
# Losses {'ner': 31.814439091729582}
# Losses {'ner': 40.44451943402237}
# Losses {'ner': 50.40791607265419}
# Losses {'ner': 56.93403505896276}
# Losses {'ner': 61.836695969934226}
# Losses {'ner': 66.46817407630442}
# Losses {'ner': 72.2921838505572}
# Losses {'ner': 82.07066563203989}
# Losses {'ner': 92.50469634369074}
# Losses {'ner': 4.816443418618292}
# Losses {'ner': 12.79289431264624}
# Losses {'ner': 17.320020146202296}
# Losses {'ner': 26.132938116323203}
# Losses {'ner': 32.4787294822745}
# Losses {'ner': 40.294594700913876}
# Losses {'ner': 48.89412637380883}
# Losses {'ner': 54.15041710762307}
# Losses {'ner': 61.0012924852781}
# Losses {'ner': 70.18835907953326}
# Losses {'ner': 76.93718189152423}
# Losses {'ner': 83.98002924176399}
# Losses {'ner': 92.90729938598815}
# Losses {'ner': 5.046453882008791}
# Losses {'ner': 12.270183850079775}
# Losses {'ner': 19.296532389707863}
# Losses {'ner': 27.608182919211686}
# Losses {'ner': 36.00799418706447}
# Losses {'ner': 41.6406110809512}
# Losses {'ner': 48.135406095101644}
# Losses {'ner': 55.45550215946059}
# Losses {'ner': 64.67077097253423}
# Losses {'ner': 70.1941761146627}
# Losses {'ner': 75.48345351920943}
# Losses {'ner': 82.82757455812316}
# Losses {'ner': 85.31943999094437}
# Losses {'ner': 8.202430803328753}
# Losses {'ner': 17.40880012139678}
# Losses {'ner': 27.383539762347937}
# Losses {'ner': 34.28599105402827}
# Losses {'ner': 41.696567794308066}
# Losses {'ner': 47.31322320736945}
# Losses {'ner': 55.48520500585437}
# Losses {'ner': 62.23566056601703}
# Losses {'ner': 71.17857424728572}
# Losses {'ner': 78.82173912785947}
# Losses {'ner': 82.50090804882348}
# Losses {'ner': 90.43199508823454}
# Losses {'ner': 98.54549239389598}
# Losses {'ner': 4.693490729434416}
# Losses {'ner': 13.688440874917433}
# Losses {'ner': 22.855965689523146}
# Losses {'ner': 28.14981452631764}
# Losses {'ner': 34.68566880072467}
# Losses {'ner': 39.98124106484465}
# Losses {'ner': 44.66105247344899}
# Losses {'ner': 52.15040530692863}
# Losses {'ner': 59.94828035831529}
# Losses {'ner': 65.18186231106597}
# Losses {'ner': 69.95784169840704}
# Losses {'ner': 79.042887356459}
# Losses {'ner': 87.0545267574264}
# Losses {'ner': 9.016132265329361}
# Losses {'ner': 13.730326967313886}
# Losses {'ner': 21.67760577239096}
# Losses {'ner': 26.18434983305633}
# Losses {'ner': 33.0782516207546}
# Losses {'ner': 34.52373605611501}
# Losses {'ner': 41.389056578453165}
# Losses {'ner': 49.22605508283914}
# Losses {'ner': 52.772115633331396}
# Losses {'ner': 61.580426797710516}
# Losses {'ner': 67.82778129211829}
# Losses {'ner': 72.9792197110105}
# Losses {'ner': 79.02894877511744}
# Losses {'ner': 6.515315508004278}
# Losses {'ner': 16.871236657258123}
# Losses {'ner': 25.69065681612119}
# Losses {'ner': 32.64584521576762}
# Losses {'ner': 38.704583544284105}
# Losses {'ner': 49.05301650241017}
# Losses {'ner': 57.59535322710872}
# Losses {'ner': 67.07903722673655}
# Losses {'ner': 74.11580993514508}
# Losses {'ner': 78.60178027953953}
# Losses {'ner': 82.80714528542012}
# Losses {'ner': 87.03834086935967}
# Losses {'ner': 93.43741592857987}
# Losses {'ner': 2.6703802458941936}
# Losses {'ner': 9.275881002657115}
# Losses {'ner': 16.013105906778947}
# Losses {'ner': 23.33502871566452}
# Losses {'ner': 29.800425462657586}
# Losses {'ner': 35.17752765887417}
# Losses {'ner': 41.33149634883739}
# Losses {'ner': 49.86467673466541}
# Losses {'ner': 57.046657173195854}
# Losses {'ner': 66.67210554913618}
# Losses {'ner': 72.5438311828766}
# Losses {'ner': 79.34013643697836}
# Losses {'ner': 88.86420917348005}
# Losses {'ner': 8.82475557923317}
# Losses {'ner': 16.93251297622919}
# Losses {'ner': 24.71386426128447}
# Losses {'ner': 33.46616196073592}
# Losses {'ner': 40.382068464532495}
# Losses {'ner': 41.703274787802115}
# Losses {'ner': 47.80494502319755}
# Losses {'ner': 51.95263859948875}
# Losses {'ner': 57.56846031120779}
# Losses {'ner': 63.335435542676464}
# Losses {'ner': 69.91581702551605}
# Losses {'ner': 74.89229714747319}
# Losses {'ner': 83.8440700757111}
# Losses {'ner': 7.44771053083241}
# Losses {'ner': 12.69750967528671}
# Losses {'ner': 18.47808288782835}
# Losses {'ner': 27.462232306599617}
# Losses {'ner': 32.49575424939394}
# Losses {'ner': 37.14699526783079}
# Losses {'ner': 43.05701872194186}
# Losses {'ner': 50.43864208692685}
# Losses {'ner': 59.361057119909674}
# Losses {'ner': 60.91393772745505}
# Losses {'ner': 68.29590582381934}
# Losses {'ner': 77.32958876620978}
# Losses {'ner': 84.84976770938374}
# Losses {'ner': 6.843631320545683}
# Losses {'ner': 12.022866591319321}
# Losses {'ner': 17.56370987880218}
# Losses {'ner': 21.20698809388268}
# Losses {'ner': 27.74993741276848}
# Losses {'ner': 31.073244546831784}
# Losses {'ner': 40.37940465408677}
# Losses {'ner': 49.23572801548356}
# Losses {'ner': 56.867128656537474}
# Losses {'ner': 64.64022192015612}
# Losses {'ner': 70.06459327071273}
# Losses {'ner': 77.08151918678844}
# Losses {'ner': 84.64296606212223}
# Losses {'ner': 5.113339614123106}
# Losses {'ner': 12.247995200916193}
# Losses {'ner': 20.00944877730217}
# Losses {'ner': 29.710210572346114}
# Losses {'ner': 37.02807582251262}
# Losses {'ner': 45.22371931455564}
# Losses {'ner': 50.375681594829075}
# Losses {'ner': 58.79729108221363}
# Losses {'ner': 63.20947022351902}
# Losses {'ner': 73.12455297622364}
# Losses {'ner': 76.81974481011275}
# Losses {'ner': 83.27069058979396}
# Losses {'ner': 90.43162983621005}
# Losses {'ner': 3.9704574309289455}
# Losses {'ner': 12.19996428117156}
# Losses {'ner': 19.307604547590017}
# Losses {'ner': 25.634898762218654}
# Losses {'ner': 32.76933720242232}
# Losses {'ner': 41.98883018794004}
# Losses {'ner': 46.1772453855956}
# Losses {'ner': 50.3905904503772}
# Losses {'ner': 56.99545629124623}
# Losses {'ner': 66.07311917643528}
# Losses {'ner': 75.06920476059895}
# Losses {'ner': 84.34002436499577}
# Losses {'ner': 92.15336568083148}
# Losses {'ner': 9.589492201805115}
# Losses {'ner': 18.02229519188404}
# Losses {'ner': 20.226827170699835}
# Losses {'ner': 28.561608337331563}
# Losses {'ner': 33.54225461790338}
# Losses {'ner': 41.50407629320398}
# Losses {'ner': 48.074249556753784}
# Losses {'ner': 57.480979493353516}
# Losses {'ner': 64.09874942013994}
# Losses {'ner': 70.53928331891075}
# Losses {'ner': 75.58256614068523}
# Losses {'ner': 83.4625502047129}
# Losses {'ner': 92.2418181549292}
# Losses {'ner': 6.6224991753697395}
# Losses {'ner': 13.500132210552692}
# Losses {'ner': 16.84186367946677}
# Losses {'ner': 24.181782089872286}
# Losses {'ner': 29.205456784693524}
# Losses {'ner': 35.311394315285725}
# Losses {'ner': 41.19840703539376}
# Losses {'ner': 50.60683697841887}
# Losses {'ner': 56.52976859740738}
# Losses {'ner': 64.10841026909475}
# Losses {'ner': 66.60302140745625}
# Losses {'ner': 75.84389271023974}
# Losses {'ner': 82.4782014805387}
# Losses {'ner': 5.810072481632233}
# Losses {'ner': 6.807428245432675}
# Losses {'ner': 13.62561418581754}
# Losses {'ner': 20.241825895383954}
# Losses {'ner': 28.85049787349999}
# Losses {'ner': 38.49029788561165}
# Losses {'ner': 40.47480414924212}
# Losses {'ner': 46.0345637651626}
# Losses {'ner': 50.610198959941044}
# Losses {'ner': 56.42889104830101}
# Losses {'ner': 62.63185574533418}
# Losses {'ner': 68.36112783197314}
# Losses {'ner': 73.29103813203983}
# Losses {'ner': 8.302249623928219}
# Losses {'ner': 16.64378454023972}
# Losses {'ner': 20.332313865423203}
# Losses {'ner': 23.072382509708405}
# Losses {'ner': 31.862478513736278}
# Losses {'ner': 40.25234051278676}
# Losses {'ner': 49.86280070475186}
# Losses {'ner': 54.499041075323476}
# Losses {'ner': 60.70783717787708}
# Losses {'ner': 64.95154801217723}
# Losses {'ner': 74.44749924747157}
# Losses {'ner': 82.50265738388407}
# Losses {'ner': 91.88888302465784}
# Losses {'ner': 7.3417358957231045}
# Losses {'ner': 13.986862784484401}
# Losses {'ner': 22.080031401710585}
# Losses {'ner': 28.138614258961752}
# Losses {'ner': 35.57046569813974}
# Losses {'ner': 36.742175980471075}
# Losses {'ner': 43.02099899854511}
# Losses {'ner': 48.86588848440442}
# Losses {'ner': 58.04796942381654}
# Losses {'ner': 66.60979039466474}
# Losses {'ner': 74.00171759945806}
# Losses {'ner': 80.99125911516603}
# Losses {'ner': 90.28404087049421}
# Losses {'ner': 6.969706296920776}
# Losses {'ner': 11.736502081155777}
# Losses {'ner': 17.94134971871972}
# Losses {'ner': 23.270984443835914}
# Losses {'ner': 32.10835357848555}
# Losses {'ner': 39.686003532639006}
# Losses {'ner': 43.44595342539833}
# Losses {'ner': 54.28148698472069}
# Losses {'ner': 58.77575688326215}
# Losses {'ner': 65.89317414496509}
# Losses {'ner': 72.12260744307605}
# Losses {'ner': 80.79628093500105}
# Losses {'ner': 85.56270259485063}
# Losses {'ner': 3.5064173322170973}
# Losses {'ner': 9.69474504608661}
# Losses {'ner': 16.96374118514359}
# Losses {'ner': 23.928379701450467}
# Losses {'ner': 29.887974897399545}
# Losses {'ner': 36.627997948788106}
# Losses {'ner': 40.75857159215957}
# Losses {'ner': 46.533394392579794}
# Losses {'ner': 49.52352423989214}
# Losses {'ner': 56.381047234172}
# Losses {'ner': 60.84123842814006}
# Losses {'ner': 66.36221490218304}
# Losses {'ner': 73.39003387658158}
# Losses {'ner': 7.615865811705589}
# Losses {'ner': 13.053469974547625}
# Losses {'ner': 19.703126598149538}
# Losses {'ner': 22.57093688985333}
# Losses {'ner': 28.481050258036703}
# Losses {'ner': 36.43411133205518}
# Losses {'ner': 39.200244369218126}
# Losses {'ner': 44.52203619573265}
# Losses {'ner': 51.67762076947838}
# Losses {'ner': 61.41149814520031}
# Losses {'ner': 69.41305792983621}
# Losses {'ner': 74.79943939272198}
# Losses {'ner': 81.75351922173286}
# Losses {'ner': 7.599970743060112}
# Losses {'ner': 14.837494870647788}
# Losses {'ner': 22.89228493766859}
# Losses {'ner': 27.959237823259173}
# Losses {'ner': 34.583458930250345}
# Losses {'ner': 37.47859423310365}
# Losses {'ner': 41.714735414392635}
# Losses {'ner': 49.51402027488439}
# Losses {'ner': 55.596164150189}
# Losses {'ner': 59.764546337795764}
# Losses {'ner': 63.353991057283565}
# Losses {'ner': 67.37019996766685}
# Losses {'ner': 74.51049824480651}
# Losses {'ner': 7.406862661242485}
# Losses {'ner': 15.803874976933002}
# Losses {'ner': 22.892667181789875}
# Losses {'ner': 23.891221206547925}
# Losses {'ner': 30.12096120035858}
# Losses {'ner': 35.67993752742768}
# Losses {'ner': 40.72097289246366}
# Losses {'ner': 48.73180520940431}
# Losses {'ner': 56.67017329331346}
# Losses {'ner': 60.82714845087238}
# Losses {'ner': 69.29815925504872}
# Losses {'ner': 76.43581396002182}
# Losses {'ner': 85.24430770832905}
# Losses {'ner': 5.594301211182028}
# Losses {'ner': 10.231266673072241}
# Losses {'ner': 17.379452105029486}
# Losses {'ner': 24.322066620807163}
# Losses {'ner': 29.73443604435306}
# Losses {'ner': 36.7721905837534}
# Losses {'ner': 44.112203883822076}
# Losses {'ner': 49.825897822505794}
# Losses {'ner': 56.0105067997938}
# Losses {'ner': 64.59233980474528}
# Losses {'ner': 69.82410529849585}
# Losses {'ner': 77.77474421577062}
# Losses {'ner': 86.79192301945295}
# Losses {'ner': 4.965507563203573}
# Losses {'ner': 11.61041172966361}
# Losses {'ner': 17.78604555223137}
# Losses {'ner': 26.71783454809338}
# Losses {'ner': 34.166710915414825}
# Losses {'ner': 41.024941111354366}
# Losses {'ner': 48.88498838981448}
# Losses {'ner': 53.299024199040815}
# Losses {'ner': 60.74240321842788}
# Losses {'ner': 67.68060769317506}
# Losses {'ner': 73.03709544977008}
# Losses {'ner': 77.74815370878039}
# Losses {'ner': 83.28211222207008}
# Losses {'ner': 4.561762867495418}
# Losses {'ner': 12.172333891794551}
# Losses {'ner': 18.345021746412385}
# Losses {'ner': 27.195205780502874}
# Losses {'ner': 34.598492788907606}
# Losses {'ner': 39.06027275585802}
# Losses {'ner': 43.39574443438323}
# Losses {'ner': 48.40160015487345}
# Losses {'ner': 58.12241164111765}
# Losses {'ner': 65.31884663901292}
# Losses {'ner': 72.9216002074536}
# Losses {'ner': 79.72661843872629}
# Losses {'ner': 86.51225115708075}
# Losses {'ner': 5.443519554974046}
# Losses {'ner': 11.53486112918472}
# Losses {'ner': 19.470473667315673}
# Losses {'ner': 23.619350705004763}
# Losses {'ner': 29.79076561675174}
# Losses {'ner': 38.75972688541515}
# Losses {'ner': 44.975348598498385}
# Losses {'ner': 51.16428866161732}
# Losses {'ner': 61.769077084201854}
# Losses {'ner': 65.23520226328401}
# Losses {'ner': 72.98316767363576}
# Losses {'ner': 79.49204721598653}
# Losses {'ner': 86.85180332808523}
# Losses {'ner': 6.800604336895049}
# Losses {'ner': 14.913882338441908}
# Losses {'ner': 22.647356434725225}
# Losses {'ner': 28.191022066399455}
# Losses {'ner': 31.58360742405057}
# Losses {'ner': 38.599798154085875}
# Losses {'ner': 47.03081526979804}
# Losses {'ner': 52.26058320835}
# Losses {'ner': 57.77210004761582}
# Losses {'ner': 65.16745079442626}
# Losses {'ner': 67.2565388733492}
# Losses {'ner': 75.51480822805024}
# Losses {'ner': 79.21598987914331}
# Losses {'ner': 6.81854173541069}
# Losses {'ner': 15.386906534433365}
# Losses {'ner': 22.204833328723907}
# Losses {'ner': 31.58342631161213}
# Losses {'ner': 36.371721252799034}
# Losses {'ner': 42.75636094529182}
# Losses {'ner': 50.21640726714395}
# Losses {'ner': 57.35967923491262}
# Losses {'ner': 66.48668123572133}
# Losses {'ner': 73.81126646487974}
# Losses {'ner': 76.28393967240117}
# Losses {'ner': 83.51513526379131}
# Losses {'ner': 86.73113094619475}
# Losses {'ner': 5.307483285665512}
# Losses {'ner': 11.640358863398433}
# Losses {'ner': 14.954362558631146}
# Losses {'ner': 18.406918636487717}
# Losses {'ner': 22.49778834447443}
# Losses {'ner': 29.814440784009093}
# Losses {'ner': 36.79044556850113}
# Losses {'ner': 46.703486578534466}
# Losses {'ner': 57.306120114396435}
# Losses {'ner': 65.32505242712341}
# Losses {'ner': 72.44259775243245}
# Losses {'ner': 80.07109076343022}
# Losses {'ner': 84.2342099610205}
# Losses {'ner': 7.349403187632561}
# Losses {'ner': 14.614632457494736}
# Losses {'ner': 18.806033359840512}
# Losses {'ner': 26.264041716232896}
# Losses {'ner': 30.741080702049658}
# Losses {'ner': 39.1874938912224}
# Losses {'ner': 43.20981485466473}
# Losses {'ner': 50.14990110020153}
# Losses {'ner': 55.36490269261412}
# Losses {'ner': 59.7020656268578}
# Losses {'ner': 63.452316647388216}
# Losses {'ner': 68.36406826040911}
# Losses {'ner': 76.5735719483273}
# Losses {'ner': 8.281120194122195}
# Losses {'ner': 10.770427389070392}
# Losses {'ner': 18.243563724681735}
# Losses {'ner': 25.002345575019717}
# Losses {'ner': 31.785976882485556}
# Losses {'ner': 37.19895193037519}
# Losses {'ner': 43.47763270941505}
# Losses {'ner': 48.76966091500071}
# Losses {'ner': 54.69140832304703}
# Losses {'ner': 64.266025589702}
# Losses {'ner': 71.88933955311524}
# Losses {'ner': 76.86178283298369}
# Losses {'ner': 80.46417167874034}
# Losses {'ner': 7.506813062231231}
# Losses {'ner': 10.775486432823527}
# Losses {'ner': 17.91506028628646}
# Losses {'ner': 24.42420755081548}
# Losses {'ner': 32.43369319044723}
# Losses {'ner': 38.03388617349992}
# Losses {'ner': 47.47368390275369}
# Losses {'ner': 50.00331845948676}
# Losses {'ner': 57.86317192087154}
# Losses {'ner': 59.21741065498645}
# Losses {'ner': 67.84993979450519}
# Losses {'ner': 76.6803691342866}
# Losses {'ner': 80.969552587012}
# Losses {'ner': 7.92699921131134}
# Losses {'ner': 17.012448692694306}
# Losses {'ner': 22.027562318602577}
# Losses {'ner': 28.960313154617324}
# Losses {'ner': 35.04689472191967}
# Losses {'ner': 42.54599532508291}
# Losses {'ner': 48.040013564925175}
# Losses {'ner': 54.253138704400044}
# Losses {'ner': 60.5196830315399}
# Losses {'ner': 69.843172697525}
# Losses {'ner': 76.28240455960622}
# Losses {'ner': 83.42230957088759}
# Losses {'ner': 88.42418187198928}
# Losses {'ner': 9.042420119047165}
# Losses {'ner': 15.12617065035738}
# Losses {'ner': 22.07568909996189}
# Losses {'ner': 26.18599371262826}
# Losses {'ner': 31.63135649007745}
# Losses {'ner': 37.342066251905635}
# Losses {'ner': 42.689824977191165}
# Losses {'ner': 45.310086342535214}
# Losses {'ner': 53.19901993594249}
# Losses {'ner': 61.081351731932955}
# Losses {'ner': 70.24781218639691}
# Losses {'ner': 74.92167169324239}
# Losses {'ner': 80.85904855004628}
# Losses {'ner': 6.774584882692579}
# Losses {'ner': 15.553389780954603}
# Losses {'ner': 18.758293700204376}
# Losses {'ner': 26.82227629123736}
# Losses {'ner': 32.825630279057805}
# Losses {'ner': 41.169829632071924}
# Losses {'ner': 48.589678133754205}
# Losses {'ner': 54.68513006510693}
# Losses {'ner': 60.30372235717732}
# Losses {'ner': 63.862534230142046}
# Losses {'ner': 66.86640671154964}
# Losses {'ner': 76.3444944348048}
# Losses {'ner': 82.51309257260073}
# Losses {'ner': 6.818131495223497}
# Losses {'ner': 11.914339276918327}
# Losses {'ner': 18.337931658235902}
# Losses {'ner': 26.801694656816835}
# Losses {'ner': 30.585377414805407}
# Losses {'ner': 36.52028448353667}
# Losses {'ner': 40.39392460267118}
# Losses {'ner': 48.16969909572799}
# Losses {'ner': 55.86828174495895}
# Losses {'ner': 63.49157710467989}
# Losses {'ner': 68.75257381518895}
# Losses {'ner': 77.32016756852681}
# Losses {'ner': 81.43432268222386}
# Losses {'ner': 8.141320932656527}
# Losses {'ner': 14.568359876864633}
# Losses {'ner': 20.203585590117655}
# Losses {'ner': 26.763671335645995}
# Losses {'ner': 33.06304631178318}
# Losses {'ner': 38.63972319493587}
# Losses {'ner': 46.258153809407304}
# Losses {'ner': 51.64117860811348}
# Losses {'ner': 55.831924796277235}
# Losses {'ner': 64.80278438346977}
# Losses {'ner': 73.34587252751044}
# Losses {'ner': 79.77699597719584}
# Losses {'ner': 86.68790696385076}
# Losses {'ner': 7.518329699058086}
# Losses {'ner': 14.645363290328532}
# Losses {'ner': 22.474502285476774}
# Losses {'ner': 31.750062306877226}
# Losses {'ner': 40.07247146451846}
# Losses {'ner': 46.47185012185946}
# Losses {'ner': 53.46629452193156}
# Losses {'ner': 59.999972818885}
# Losses {'ner': 64.53537805983797}
# Losses {'ner': 69.61772296437994}
# Losses {'ner': 75.4928876144113}
# Losses {'ner': 83.61789309803862}
# Losses {'ner': 88.48176121537108}
# Losses {'ner': 7.044392466545105}
# Losses {'ner': 14.065072923898697}
# Losses {'ner': 22.243449926376343}
# Losses {'ner': 25.826315097510815}
# Losses {'ner': 33.44162832945585}
# Losses {'ner': 41.640181770548224}
# Losses {'ner': 42.7709480432095}
# Losses {'ner': 50.06781463895459}
# Losses {'ner': 57.89035600994248}
# Losses {'ner': 63.87594323529629}
# Losses {'ner': 67.62589452712564}
# Losses {'ner': 74.47838834970025}
# Losses {'ner': 82.82254193534027}
# Losses {'ner': 8.200969934463501}
# Losses {'ner': 11.040081630577333}
# Losses {'ner': 16.200299976044334}
# Losses {'ner': 24.623811448807828}
# Losses {'ner': 29.423839635957847}
# Losses {'ner': 33.031820130345295}
# Losses {'ner': 41.45836867093749}
# Losses {'ner': 45.34265829603828}
# Losses {'ner': 49.72710119355179}
# Losses {'ner': 54.31411221511371}
# Losses {'ner': 61.96762417005084}
# Losses {'ner': 67.14782361713878}
# Losses {'ner': 75.11631341306202}
# Losses {'ner': 5.70166775258258}
# Losses {'ner': 13.74537130119279}
# Losses {'ner': 22.907158453483135}
# Losses {'ner': 29.188480528711807}
# Losses {'ner': 32.76281199057121}
# Losses {'ner': 39.75596973125357}
# Losses {'ner': 44.92417731706519}
# Losses {'ner': 50.878037266549654}
# Losses {'ner': 58.85562935296912}
# Losses {'ner': 66.38769420806784}
# Losses {'ner': 71.75909569386762}
# Losses {'ner': 75.66597309072871}
# Losses {'ner': 83.3764218922462}
# Losses {'ner': 6.478255156427622}
# Losses {'ner': 11.716922722989693}
# Losses {'ner': 18.33020805363776}
# Losses {'ner': 24.5259149352205}
# Losses {'ner': 32.38273283635499}
# Losses {'ner': 35.031080605171155}
# Losses {'ner': 41.340255876712035}
# Losses {'ner': 49.62647915416164}
# Losses {'ner': 56.113215870820454}
# Losses {'ner': 63.62402380786068}
# Losses {'ner': 67.5207110155751}
# Losses {'ner': 76.72726068984764}
# Losses {'ner': 83.06306677650707}
# Losses {'ner': 4.440979127306491}
# Losses {'ner': 12.109741161111742}
# Losses {'ner': 19.04532570624724}
# Losses {'ner': 25.461744899395853}
# Losses {'ner': 30.124623230585712}
# Losses {'ner': 32.877825843010214}
# Losses {'ner': 39.307658101271954}
# Losses {'ner': 46.015735446315375}
# Losses {'ner': 53.671701608996955}
# Losses {'ner': 57.11321866961953}
# Losses {'ner': 61.51773528510239}
# Losses {'ner': 66.8291634604102}
# Losses {'ner': 72.4692138772225}
# Losses {'ner': 7.716242745518684}
# Losses {'ner': 16.255028918385506}
# Losses {'ner': 20.23480702447705}
# Losses {'ner': 23.94849123689346}
# Losses {'ner': 29.55213027226273}
# Losses {'ner': 33.54138406983111}
# Losses {'ner': 40.68308342876844}
# Losses {'ner': 48.295130296377465}
# Losses {'ner': 53.8526233274024}
# Losses {'ner': 60.727314941817895}
# Losses {'ner': 68.58954624668695}
# Losses {'ner': 75.00055603426881}
# Losses {'ner': 81.59160277293995}
# Losses {'ner': 6.433593723224476}
# Losses {'ner': 12.143444628454745}
# Losses {'ner': 18.045861846301705}
# Losses {'ner': 21.434251242666505}
# Losses {'ner': 25.529806671082042}
# Losses {'ner': 29.605361354886554}
# Losses {'ner': 38.9369192373706}
# Losses {'ner': 45.51496758579742}
# Losses {'ner': 54.125852416153066}
# Losses {'ner': 58.59760622296017}
# Losses {'ner': 66.52736679825466}
# Losses {'ner': 70.7281350720441}
# Losses {'ner': 78.3578548807418}
# Losses {'ner': 6.564350016415119}
# Losses {'ner': 16.32861912995577}
# Losses {'ner': 25.51332873851061}
# Losses {'ner': 25.6584014542168}
# Losses {'ner': 32.36162033735309}
# Losses {'ner': 39.87560400424991}
# Losses {'ner': 46.64332145510707}
# Losses {'ner': 50.36613188742194}
# Losses {'ner': 54.74417487962637}
# Losses {'ner': 59.87231779756257}
# Losses {'ner': 66.72769226046512}
# Losses {'ner': 73.0946763328393}
# Losses {'ner': 78.1209696076694}
# Losses {'ner': 8.119921378791332}
# Losses {'ner': 12.96385706885485}
# Losses {'ner': 16.614887009491213}
# Losses {'ner': 20.06750851412653}
# Losses {'ner': 27.916104635660304}
# Losses {'ner': 32.0278600458696}
# Losses {'ner': 40.26310417393688}
# Losses {'ner': 46.95142660240526}
# Losses {'ner': 50.46939166213269}
# Losses {'ner': 51.76415218153852}
# Losses {'ner': 59.57358403105172}
# Losses {'ner': 63.40046265695128}
# Losses {'ner': 71.53643536675372}
# Losses {'ner': 6.175761388789397}
# Losses {'ner': 11.458184023562353}
# Losses {'ner': 17.938367870810907}
# Losses {'ner': 26.845052275049966}
# Losses {'ner': 34.5235616445425}
# Losses {'ner': 39.463937011622875}
# Losses {'ner': 44.282093689852445}
# Losses {'ner': 49.36973397534439}
# Losses {'ner': 54.37498743793094}
# Losses {'ner': 60.780733242473616}
# Losses {'ner': 65.35265471584262}
# Losses {'ner': 71.95018880402768}
# Losses {'ner': 78.69263820899778}
# Losses {'ner': 4.732396605075337}
# Losses {'ner': 13.599494422436692}
# Losses {'ner': 17.27030546059541}
# Losses {'ner': 19.778682163399935}
# Losses {'ner': 23.78746716160822}
# Losses {'ner': 27.05982542079437}
# Losses {'ner': 32.28079583766794}
# Losses {'ner': 38.39860794219112}
# Losses {'ner': 44.10538813127346}
# Losses {'ner': 49.271640284733394}
# Losses {'ner': 55.65757382689185}
# Losses {'ner': 65.24701464949317}
# Losses {'ner': 72.55859419952753}
# Losses {'ner': 5.250504647498019}
# Losses {'ner': 10.72560920577962}
# Losses {'ner': 15.910223439452238}
# Losses {'ner': 24.25412611674983}
# Losses {'ner': 30.238940842418263}
# Losses {'ner': 39.31798436489541}
# Losses {'ner': 47.615152661591736}
# Losses {'ner': 53.87845385530588}
# Losses {'ner': 61.915343896388976}
# Losses {'ner': 64.89765218244199}
# Losses {'ner': 71.09246316197593}
# Losses {'ner': 73.11123475450356}
# Losses {'ner': 74.10796028813408}
# Losses {'ner': 6.930790641112253}
# Losses {'ner': 13.140852858079597}
# Losses {'ner': 19.560780985688325}
# Losses {'ner': 19.6325333254008}
# Losses {'ner': 27.277045680728406}
# Losses {'ner': 32.3870107015191}
# Losses {'ner': 39.840217240673155}
# Losses {'ner': 43.011350590948496}
# Losses {'ner': 50.02379006517913}
# Losses {'ner': 58.06830628214266}
# Losses {'ner': 61.42722742988008}
# Losses {'ner': 67.35500527498061}
# Losses {'ner': 74.82261462275619}
# Losses {'ner': 8.605213433504105}
# Losses {'ner': 13.073072651401162}
# Losses {'ner': 20.28586128167808}
# Losses {'ner': 26.80578978266567}
# Losses {'ner': 34.94259928644169}
# Losses {'ner': 41.416366209392436}
# Losses {'ner': 45.48017697702289}
# Losses {'ner': 49.4510194071936}
# Losses {'ner': 56.298770465831694}
# Losses {'ner': 62.999568530301985}
# Losses {'ner': 69.32358362613195}
# Losses {'ner': 72.42788184440906}
# Losses {'ner': 76.21271752759094}
# Losses {'ner': 4.816352276131511}
# Losses {'ner': 12.462178868096089}
# Losses {'ner': 20.80727515820763}
# Losses {'ner': 26.6523306225572}
# Losses {'ner': 33.18730223471357}
# Losses {'ner': 41.78062227940245}
# Losses {'ner': 51.21288657760306}
# Losses {'ner': 58.81106706535502}
# Losses {'ner': 65.49838495634322}
# Losses {'ner': 72.48611442456104}
# Losses {'ner': 76.73943908945739}
# Losses {'ner': 85.73413046137512}
# Losses {'ner': 89.16839219550684}
# Losses {'ner': 3.672699550166726}
# Losses {'ner': 10.729134394543507}
# Losses {'ner': 16.575061681436637}
# Losses {'ner': 23.683572160185577}
# Losses {'ner': 29.56191215115905}
# Losses {'ner': 36.62329593497634}
# Losses {'ner': 43.71159393882408}
# Losses {'ner': 49.443600611593865}
# Losses {'ner': 56.174802915957116}
# Losses {'ner': 63.931060207141854}
# Losses {'ner': 72.99406540866039}
# Losses {'ner': 78.53656620259426}
# Losses {'ner': 82.88964279561333}
# Losses {'ner': 5.288037484700908}
# Losses {'ner': 12.513215824772487}
# Losses {'ner': 17.78621614658914}
# Losses {'ner': 24.4244178095978}
# Losses {'ner': 30.893735857258434}
# Losses {'ner': 36.24905719437811}
# Losses {'ner': 40.610535148894996}
# Losses {'ner': 48.08383832535765}
# Losses {'ner': 49.2702763763009}
# Losses {'ner': 56.30991675113546}
# Losses {'ner': 60.046510652722645}
# Losses {'ner': 68.2685986301658}
# Losses {'ner': 73.80880022708152}
# Losses {'ner': 4.442346058785915}
# Losses {'ner': 10.087756644003093}
# Losses {'ner': 16.680622637745728}
# Losses {'ner': 21.385098733525737}
# Losses {'ner': 26.66001635748522}
# Losses {'ner': 33.30451656202182}
# Losses {'ner': 39.89074016431674}
# Losses {'ner': 44.839570931674515}
# Losses {'ner': 52.26995417806653}
# Losses {'ner': 57.86163230394537}
# Losses {'ner': 65.61378058147908}
# Losses {'ner': 70.70386228812218}
# Losses {'ner': 78.86099437726021}
# Losses {'ner': 6.11812018416822}
# Losses {'ner': 11.008849849924445}
# Losses {'ner': 18.507090359044014}
# Losses {'ner': 20.430533154582008}
# Losses {'ner': 28.607925097259795}
# Losses {'ner': 35.746131378056816}
# Losses {'ner': 43.2938776662977}
# Losses {'ner': 49.85973153025225}
# Losses {'ner': 58.71857986361101}
# Losses {'ner': 65.31770659791619}
# Losses {'ner': 74.05393824534804}
# Losses {'ner': 78.451782675902}
# Losses {'ner': 82.59780100334865}
# Losses {'ner': 5.355969334450492}
# Losses {'ner': 11.407161504255782}
# Losses {'ner': 17.45916449897095}
# Losses {'ner': 23.975246033835447}
# Losses {'ner': 31.09004894571308}
# Losses {'ner': 35.30892167167667}
# Losses {'ner': 38.91324934173508}
# Losses {'ner': 42.06546657674818}
# Losses {'ner': 48.56287589730101}
# Losses {'ner': 54.28381617754104}
# Losses {'ner': 63.07694928734901}
# Losses {'ner': 68.09153724289837}
# Losses {'ner': 74.75731232916343}
# Losses {'ner': 8.351295540109277}
# Losses {'ner': 16.772277424111962}
# Losses {'ner': 24.157545814290643}
# Losses {'ner': 31.794332722201943}
# Losses {'ner': 36.026594100752845}
# Losses {'ner': 41.93753239169018}
# Losses {'ner': 47.881560039066244}
# Losses {'ner': 51.50582714966731}
# Losses {'ner': 58.89688340417342}
# Losses {'ner': 69.20611914090114}
# Losses {'ner': 74.98764399095671}
# Losses {'ner': 82.40959886857809}
# Losses {'ner': 87.07514885021874}
# Losses {'ner': 6.217503344756551}
# Losses {'ner': 13.560945978504606}
# Losses {'ner': 20.37800455663819}
# Losses {'ner': 27.95474050019402}
# Losses {'ner': 35.52657551143784}
# Losses {'ner': 43.334122104686685}
# Losses {'ner': 50.47338346380275}
# Losses {'ner': 56.90939665574115}
# Losses {'ner': 57.03114637732506}
# Losses {'ner': 65.76557646691799}
# Losses {'ner': 70.1077927503502}
# Losses {'ner': 75.27086059225257}
# Losses {'ner': 80.78934604203096}
# Losses {'ner': 5.16245511849047}
# Losses {'ner': 12.096583732633007}
# Losses {'ner': 16.19445113441543}
# Losses {'ner': 21.413531791971764}
# Losses {'ner': 29.358902376698097}
# Losses {'ner': 35.97692696619197}
# Losses {'ner': 43.536791427613935}
# Losses {'ner': 52.64267454337096}
# Losses {'ner': 57.89043182920432}
# Losses {'ner': 61.54767135770453}
# Losses {'ner': 69.51410649211539}
# Losses {'ner': 77.5459600785507}
# Losses {'ner': 82.31510160008838}
# Losses {'ner': 5.8032766753239}
# Losses {'ner': 10.379814398096528}
# Losses {'ner': 16.2887494683672}
# Losses {'ner': 21.22987371993065}
# Losses {'ner': 27.48583758866895}
# Losses {'ner': 33.01357002055753}
# Losses {'ner': 39.679467859328874}
# Losses {'ner': 47.773879888118394}
# Losses {'ner': 54.70925782491978}
# Losses {'ner': 56.133239880215946}
# Losses {'ner': 63.10195753305462}
# Losses {'ner': 71.20869246079829}
# Losses {'ner': 77.36766503045725}
# Losses {'ner': 7.2143545262515545}
# Losses {'ner': 13.639294555061497}
# Losses {'ner': 18.594038417213596}
# Losses {'ner': 20.93977912075934}
# Losses {'ner': 25.739110782073112}
# Losses {'ner': 32.996675696202146}
# Losses {'ner': 38.619384046622145}
# Losses {'ner': 44.014502921849726}
# Losses {'ner': 52.666802743226526}
# Losses {'ner': 58.88730987325334}
# Losses {'ner': 64.75996264556099}
# Losses {'ner': 71.72753505149532}
# Losses {'ner': 77.80535340806611}
# Losses {'ner': 4.479353198155238}
# Losses {'ner': 13.749580391987635}
# Losses {'ner': 16.71094432641557}
# Losses {'ner': 24.70904034544519}
# Losses {'ner': 31.165494128649968}
# Losses {'ner': 37.41804358959352}
# Losses {'ner': 44.30476619899427}
# Losses {'ner': 50.90513601005232}
# Losses {'ner': 59.06617665141975}
# Losses {'ner': 65.91885676272186}
# Losses {'ner': 71.82206975705894}
# Losses {'ner': 75.63408027626546}
# Losses {'ner': 83.82932780720266}
# Losses {'ner': 5.176666686311364}
# Losses {'ner': 9.781432797965863}
# Losses {'ner': 14.938326817939014}
# Losses {'ner': 21.246635700577826}
# Losses {'ner': 25.731919387822927}
# Losses {'ner': 32.523760753219904}
# Losses {'ner': 34.5025226774851}
# Losses {'ner': 40.14887297489258}
# Losses {'ner': 46.862860319768515}
# Losses {'ner': 54.496100877393474}
# Losses {'ner': 61.67242107259153}
# Losses {'ner': 69.55323604958176}
# Losses {'ner': 72.76957828936429}
# Losses {'ner': 4.9503439287800575}
# Losses {'ner': 10.912612107771565}
# Losses {'ner': 18.107491765143237}
# Losses {'ner': 25.99661559894699}
# Losses {'ner': 33.794601833252415}
# Losses {'ner': 41.484728729156956}
# Losses {'ner': 46.52674016895722}
# Losses {'ner': 55.32727918568085}
# Losses {'ner': 61.78607249054144}
# Losses {'ner': 64.63158017298485}
# Losses {'ner': 71.45164309343602}
# Losses {'ner': 77.45681784106671}
# Losses {'ner': 84.00820063604294}
# Losses {'ner': 5.404886805219576}
# Losses {'ner': 12.697681409073994}
# Losses {'ner': 15.594956047889227}
# Losses {'ner': 22.20023331610524}
# Losses {'ner': 30.027373217676413}
# Losses {'ner': 33.86293566547634}
# Losses {'ner': 37.66247909464242}
# Losses {'ner': 42.40415558699702}
# Losses {'ner': 49.92895144704913}
# Losses {'ner': 58.099967544117916}
# Losses {'ner': 59.90178816475769}
# Losses {'ner': 66.75851802983185}
# Losses {'ner': 72.77968106596914}
# Losses {'ner': 5.3767200987786055}
# Losses {'ner': 14.203033505007625}
# Losses {'ner': 16.81597378279548}
# Losses {'ner': 22.014104202273302}
# Losses {'ner': 27.600005945453205}
# Losses {'ner': 35.33433388466236}
# Losses {'ner': 42.05963757612497}
# Losses {'ner': 49.18833176490605}
# Losses {'ner': 56.34289686080754}
# Losses {'ner': 64.64296748188079}
# Losses {'ner': 71.08671153035701}
# Losses {'ner': 79.0614041581446}
# Losses {'ner': 85.10891411524952}
# Losses {'ner': 4.998715907335281}
# Losses {'ner': 13.479484675495769}
# Losses {'ner': 17.11031092592748}
# Losses {'ner': 24.56894744076999}
# Losses {'ner': 28.141719302919228}
# Losses {'ner': 33.28694483340951}
# Losses {'ner': 39.8581467929298}
# Losses {'ner': 48.58235234646145}
# Losses {'ner': 53.28896148730003}
# Losses {'ner': 60.09479715157234}
# Losses {'ner': 67.09431854490124}
# Losses {'ner': 71.84394767770011}
# Losses {'ner': 79.60582134017189}
# Losses {'ner': 5.804768957197666}
# Losses {'ner': 11.534614034209426}
# Losses {'ner': 15.864554159439194}
# Losses {'ner': 21.29945217827617}
# Losses {'ner': 28.26943816746416}
# Losses {'ner': 34.69439223910513}
# Losses {'ner': 41.9585435738677}
# Losses {'ner': 45.83269562023406}
# Losses {'ner': 49.19645269848593}
# Losses {'ner': 56.89623712526122}
# Losses {'ner': 65.0217929981784}
# Losses {'ner': 74.18999718652526}
# Losses {'ner': 77.65520211832086}
# Losses {'ner': 3.903751550529705}
# Losses {'ner': 8.699881157193886}
# Losses {'ner': 13.570174445874727}
# Losses {'ner': 17.845020828313864}
# Losses {'ner': 21.735593091241753}
# Losses {'ner': 28.511142460174597}
# Losses {'ner': 35.38669384039167}
# Losses {'ner': 39.940301609702146}
# Losses {'ner': 45.422308736491686}
# Losses {'ner': 47.767844289230894}
# Losses {'ner': 55.58969208567102}
# Losses {'ner': 61.45103520123918}
# Losses {'ner': 70.00529950826127}
# Losses {'ner': 3.8033975930375163}
# Losses {'ner': 10.010303136841685}
# Losses {'ner': 15.91464956379059}
# Losses {'ner': 22.559913540208072}
# Losses {'ner': 29.34069051134429}
# Losses {'ner': 37.755132295969815}
# Losses {'ner': 44.21972126591572}
# Losses {'ner': 54.02896163690457}
# Losses {'ner': 58.6251042642034}
# Losses {'ner': 64.7287944441996}
# Losses {'ner': 71.08993842810014}
# Losses {'ner': 76.72608047335962}
# Losses {'ner': 82.16203386763664}
# Losses {'ner': 7.276224706598441}
# Losses {'ner': 15.07726943893067}
# Losses {'ner': 22.30102620155958}
# Losses {'ner': 28.442586198380013}
# Losses {'ner': 36.67617340379002}
# Losses {'ner': 40.21799560070576}
# Losses {'ner': 46.373424274857825}
# Losses {'ner': 47.89791822527695}
# Losses {'ner': 54.00037723873902}
# Losses {'ner': 59.52613355674475}
# Losses {'ner': 63.69885926403731}
# Losses {'ner': 69.87326371333256}
# Losses {'ner': 73.01392364136336}
# Losses {'ner': 3.194730981369503}
# Losses {'ner': 6.804832863039337}
# Losses {'ner': 15.555653410381638}
# Losses {'ner': 20.38638311845716}
# Losses {'ner': 27.56522134167608}
# Losses {'ner': 33.658614516607486}
# Losses {'ner': 40.429335155898116}
# Losses {'ner': 43.97373130116739}
# Losses {'ner': 49.3638681444163}
# Losses {'ner': 57.33329634096572}
# Losses {'ner': 64.67402884944227}
# Losses {'ner': 68.04899836185564}
# Losses {'ner': 74.67111455503095}
# Losses {'ner': 2.6265519349253736}
# Losses {'ner': 9.359050930885132}
# Losses {'ner': 18.093102595885284}
# Losses {'ner': 25.00784200860653}
# Losses {'ner': 31.444473866955377}
# Losses {'ner': 37.75945685630268}
# Losses {'ner': 41.64305958164459}
# Losses {'ner': 45.43211371836787}
# Losses {'ner': 49.57824254710704}
# Losses {'ner': 55.71160066243738}
# Losses {'ner': 62.206474934932885}
# Losses {'ner': 68.38069747876852}
# Losses {'ner': 69.83289212683081}
# Losses {'ner': 7.195721080497606}
# Losses {'ner': 10.07891729536641}
# Losses {'ner': 15.221839517980698}
# Losses {'ner': 23.946489453941467}
# Losses {'ner': 31.389012009531143}
# Losses {'ner': 37.583032584385364}
# Losses {'ner': 38.64357488042151}
# Losses {'ner': 45.280403602388105}
# Losses {'ner': 52.73734502818843}
# Losses {'ner': 59.580195430185995}
# Losses {'ner': 63.5138924576313}
# Losses {'ner': 70.04301969781227}
# Losses {'ner': 77.62211049201551}
# Losses {'ner': 4.995986353605986}
# Losses {'ner': 10.309124860912561}
# Losses {'ner': 17.94189867004752}
# Losses {'ner': 22.975012346636504}
# Losses {'ner': 29.699799505222927}
# Losses {'ner': 35.59137911179323}
# Losses {'ner': 45.71568596937914}
# Losses {'ner': 52.57749109870974}
# Losses {'ner': 57.6557994413547}
# Losses {'ner': 63.943319611566494}
# Losses {'ner': 71.05448717232002}
# Losses {'ner': 77.87666579662846}
# Losses {'ner': 82.56323057297641}
# Losses {'ner': 3.3107349406927824}
# Losses {'ner': 9.523982799812984}
# Losses {'ner': 12.220297981214571}
# Losses {'ner': 16.908635441374827}
# Losses {'ner': 25.376841131758738}
# Losses {'ner': 33.16269864478181}
# Losses {'ner': 38.62564369141273}
# Losses {'ner': 45.703385388843344}
# Losses {'ner': 52.131148700617814}
# Losses {'ner': 57.693019070830815}
# Losses {'ner': 63.09832815935897}
# Losses {'ner': 67.6243279462442}
# Losses {'ner': 71.38306405001731}
# Losses {'ner': 7.843566718511283}
# Losses {'ner': 12.210347197018564}
# Losses {'ner': 15.026010249741375}
# Losses {'ner': 22.60051262844354}
# Losses {'ner': 31.261218671686947}
# Losses {'ner': 36.72261346038431}
# Losses {'ner': 45.381227037869394}
# Losses {'ner': 49.54049768927507}
# Losses {'ner': 56.582146822242066}
# Losses {'ner': 63.17096462729387}
# Losses {'ner': 71.2785547299718}
# Losses {'ner': 76.7337642674338}
# Losses {'ner': 82.32494373517147}
# Losses {'ner': 5.1574710149434395}
# Losses {'ner': 7.105940244859539}
# Losses {'ner': 9.286789756035887}
# Losses {'ner': 15.130656006571826}
# Losses {'ner': 19.87089555972534}
# Losses {'ner': 26.423850280407805}
# Losses {'ner': 35.39636289811506}
# Losses {'ner': 40.45950039214267}
# Losses {'ner': 48.88216691202297}
# Losses {'ner': 53.188918330881734}
# Losses {'ner': 57.51185079774632}
# Losses {'ner': 65.98746076336874}
# Losses {'ner': 72.39454250247886}
# Losses {'ner': 5.809288816526532}
# Losses {'ner': 15.515703098848462}
# Losses {'ner': 23.378894167020917}
# Losses {'ner': 28.254202040825476}
# Losses {'ner': 33.95153746286451}
# Losses {'ner': 39.3048460064274}
# Losses {'ner': 44.815648569707264}
# Losses {'ner': 47.03856540940615}
# Losses {'ner': 50.3161923708758}
# Losses {'ner': 56.20756877912936}
# Losses {'ner': 59.966217230547045}
# Losses {'ner': 68.27813884942589}
# Losses {'ner': 74.37318547396717}
# Losses {'ner': 4.844763619825244}
# Losses {'ner': 12.686112591421988}
# Losses {'ner': 20.567401696818706}
# Losses {'ner': 27.80090286362247}
# Losses {'ner': 31.338611342136574}
# Losses {'ner': 37.397929169361305}
# Losses {'ner': 45.01757446688862}
# Losses {'ner': 51.54557699460565}
# Losses {'ner': 55.495370745025866}
# Losses {'ner': 63.047849237285845}
# Losses {'ner': 68.94629635784804}
# Losses {'ner': 75.21032357338845}
# Losses {'ner': 79.24940132199117}
# Losses {'ner': 9.288988828659058}
# Losses {'ner': 14.715035344008356}
# Losses {'ner': 21.522815046217147}
# Losses {'ner': 25.036034898537764}
# Losses {'ner': 31.684122064787516}
# Losses {'ner': 37.34314581129365}
# Losses {'ner': 41.87306165072732}
# Losses {'ner': 44.376294935998885}
# Losses {'ner': 52.840196195003955}
# Losses {'ner': 56.49483101599981}
# Losses {'ner': 63.355473389561666}
# Losses {'ner': 70.70981231023688}
# Losses {'ner': 76.2043410718361}
# Losses {'ner': 6.451401371508837}
# Losses {'ner': 11.970240022071607}
# Losses {'ner': 15.012422856090211}
# Losses {'ner': 23.24045329951457}
# Losses {'ner': 26.508648320480802}
# Losses {'ner': 36.377026840492704}
# Losses {'ner': 44.092472955032804}
# Losses {'ner': 50.96452171342514}
# Losses {'ner': 54.126990068748796}
# Losses {'ner': 60.03317623217424}
# Losses {'ner': 65.0618999739612}
# Losses {'ner': 72.42373407103912}
# Losses {'ner': 76.9219962376668}
# Losses {'ner': 5.828980686084833}
# Losses {'ner': 13.255246581451502}
# Losses {'ner': 21.603800030366983}
# Losses {'ner': 26.880284315091558}
# Losses {'ner': 30.639496195683023}
# Losses {'ner': 36.07632425762131}
# Losses {'ner': 44.31455773449852}
# Losses {'ner': 50.370168079884024}
# Losses {'ner': 53.29469422742841}
# Losses {'ner': 59.75325469186646}
# Losses {'ner': 64.0895631115709}
# Losses {'ner': 72.44987439623219}
# Losses {'ner': 81.49267613401753}
# Losses {'ner': 5.922546207904816}
# Losses {'ner': 12.112703254912049}
# Losses {'ner': 17.386566766072065}
# Losses {'ner': 23.699307261500508}
# Losses {'ner': 29.154123344767868}
# Losses {'ner': 35.628055938828766}
# Losses {'ner': 43.35313856539506}
# Losses {'ner': 49.31206853392723}
# Losses {'ner': 55.5665737808049}
# Losses {'ner': 58.359024100082024}
# Losses {'ner': 62.5793270770173}
# Losses {'ner': 65.61175983224166}
# Losses {'ner': 74.33659251278368}
# Losses {'ner': 7.7741285997508385}
# Losses {'ner': 11.614008619933884}
# Losses {'ner': 15.777511678188603}
# Losses {'ner': 20.638253451634228}
# Losses {'ner': 26.84095891078323}
# Losses {'ner': 33.94520357602596}
# Losses {'ner': 40.99362183713674}
# Losses {'ner': 45.99734938998563}
# Losses {'ner': 53.03192188559888}
# Losses {'ner': 58.05368226132987}
# Losses {'ner': 63.6649164410278}
# Losses {'ner': 70.77312943357674}
# Losses {'ner': 75.09785741585938}
# Losses {'ner': 3.9467495990684256}
# Losses {'ner': 6.878578153788112}
# Losses {'ner': 11.28197181026917}
# Losses {'ner': 15.368293979787722}
# Losses {'ner': 21.58185201941569}
# Losses {'ner': 30.251501799212292}
# Losses {'ner': 36.98609056149189}
# Losses {'ner': 41.63658241566782}
# Losses {'ner': 48.82621437881653}
# Losses {'ner': 55.55456895533325}
# Losses {'ner': 58.6926200410021}
# Losses {'ner': 66.05938747121445}
# Losses {'ner': 71.2840966532608}

# %%
for text, _ in train:
  doc=nlp(text)
  print("entities",[(ent.text,ent.label_) for ent in doc.ents])
# Out:
# entities [('balance', 'ACTIVITY'), ('savings Account', 'PRODUCT')]
# entities [('Investment Account', 'PRODUCT')]
# entities [('mortgage', 'PRODUCT'), ('delinquent', 'ACTIVITY')]
# entities [('credit card', 'PRODUCT'), ('past', 'ACTIVITY')]
# entities [('credit card', 'PRODUCT')]
# entities [('open', 'ACTIVITY'), ('loan account', 'PRODUCT')]
# entities [('opening', 'ACTIVITY'), ('savings account', 'PRODUCT')]
# entities [('open', 'ACTIVITY'), ('loan account', 'PRODUCT')]
# entities [('loan account', 'PRODUCT'), ('not approved', 'ACTIVITY'), ('funded', 'PRODUCT')]
# entities [('payment', 'ACTIVITY'), ('credit card', 'PRODUCT')]
# entities [('crdit card', 'PRODUCT')]
# entities [('paymnet', 'ACTIVITY'), ('card', 'PRODUCT')]
# entities [('checking account', 'PRODUCT')]

# %%
from spacy import displacy

doc = nlp("what is the process to open  an new savings account")

for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)

displacy.render(nlp(doc.text),style='ent',jupyter=True)
# Out:
# savings account 35 50 PRODUCT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">what is the processto open  an new
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     savings account
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>

# %%
from spacy import displacy

doc = nlp("My credit card payment will be delayed")

for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)

displacy.render(nlp(doc.text),style='ent',jupyter=True)
# Out:
# credit card 3 14 PRODUCT
# payment 15 22 ACTIVITY
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">My
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     credit card
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     payment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ACTIVITY</span>
# </mark>
#  will be delayed</div></span>

# %%
doc = nlp("what are the charges on credit card late payment in Bank of America")

for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)
displacy.render(nlp(doc.text),style='ent',jupyter=True)
# Out:
# /usr/lib/python3.6/runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">what are the charges on credit card late payment in Bank of America</div></span>

# %%
doc = nlp("I lost my investment account password and cannot open my account now")

for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)
displacy.render(nlp(doc.text),style='ent',jupyter=True)
# Out:
# investment account 10 28 PRODUCT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I lost my
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     investment account
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  password and cannot open my account now</div></span>

# %%
doc = nlp("what is the status of my loan account")

for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)
displacy.render(nlp(doc.text),style='ent',jupyter=True)
# Out:
# loan account 25 37 PRODUCT
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">what is the status of my
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     loan account
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>

# %% [markdown]
# https://explosion.ai/blog/pseudo-rehearsal-catastrophic-forgetting

# %%
doc = nlp("Australia wants to force Facebook and Google to pay media companies for news")

for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)
displacy.render(nlp(doc.text),style='ent',jupyter=True)
# Out:
# /usr/lib/python3.6/runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Australia wants to force Facebook and Google to pay media companies for news</div></span>
